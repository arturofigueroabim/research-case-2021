# %%
import numpy as np
import pandas as pd
import spacy
from spacy.tokens import Doc, Span, Token
nlp = spacy.load("en_core_web_md")
import re

from itertools import chain

# %%
#from spacy import displacy
#import deplacy

# %%
doc_features = ['num_tokens', 'para_starts']
span_features = ['word_emb', 'num_tokens', 'num_verbs', 'num_pos_pronouns', 'num_conj_adv', 'num_punct', 'is_para_start',
                 'index_in_doc']

# getters that are not used as features
span_utilities = ['prev_unit', 'label', 'idx_start', 'idx_end']
# methods
span_methods = ['get_nth_unit', 'get_prev_unit_attr', 'get_label_and_error']
token_features =['word_emb']



extensions_dict = dict(doc_features=doc_features, span_features=span_features+span_utilities,
                       token_features=token_features, span_methods=span_methods)





def create_extensions(extensions_dict=None, force=True):
    
    # Features that take 'unit' as input refer to the segmentation, they do not work with just any span.
    
    # Property attributes
    
    # Store starting and ending indices of spans in the whole doc
    # 1 list per each document: [(s1_start, s1_end), (s2_start, s2_end),.., (sn_start, sn_end)]
    Doc.set_extension("units_index_list", default=[],force=True)
    
    # Store essay_id within doc
    Doc.set_extension("essay_id", default=None, force=True)

    
    # Feature Getters
    def get_label_and_error(unit, error_function='percentage_correctness'):
        """
        Inputs: unit

        Outputs: label for the unit and segmentation error

        """

        def overlap_case(unit_start, unit_end, adu_start, adu_end):
            if adu_start >= unit_start and adu_end <= unit_end:
                # Case 1, ADU is fully contained in UNIT
                return 1

            elif adu_start <= unit_start and adu_end <=unit_end and adu_end>=unit_start:

                # Case 2, ADU starts before UNIT, start(Left) of ADU is cut
                return 2

            elif adu_start >= unit_start and adu_end >= unit_end and adu_start<unit_end:

                # Case 3, ADU starts after UNIT, end(Right) of ADU is cut
                return 3

            elif adu_start < unit_start and adu_end > unit_end:

                # Case 4, ADU starts before UNIT and ends after UNIT, both sides of ADU are cut
                return 4

            else: 
                # ADU does not overlap with UNIT
                return False
            

        def percentage_correctness(unit, adu_start, adu_end, overlap_case):

            if overlap_case==2:
                adu_start = unit._.idx_start
            if overlap_case==3:
                adu_end = unit._.idx_end

            adu = unit.doc.char_span(adu_start, adu_end, alignment_mode='expand')
            

            unit_ntokens = len(unit)
            adu_ntokens = len(adu)
            pct_correct = adu_ntokens/unit_ntokens
            return pct_correct

        def extended_accuracy(unit, adu_start, adu_end, overlap_case):
            # Compares number of tokens to get the the correct ADU in proportional with UNIT length

            if overlap_case==2:
                adu_start = unit._.idx_start
            if overlap_case==3:
                adu_end = unit._.idx_end
            adu = unit.doc.char_span(adu_start, adu_end, alignment_mode='expand')

            unit_ntokens = len(unit)
            adu_ntokens = len(adu)
            diff_ntokens = np.abs(unit_ntokens - adu_ntokens)

            return 1/((diff_ntokens+1)**(np.log2(diff_ntokens+1)/np.log2(unit_ntokens+1)))


        if error_function.lower() == 'percentage_correctness':
            err_func = percentage_correctness
        elif error_function.lower() == 'extended_accuracy':
            err_func = extended_accuracy
        
        unit_start = unit._.idx_start
        unit_end = unit._.idx_end

        essay_id = unit.doc._.essay_id

        # DataFrame containing ADUs indices & labels, filtered for current essay_id
        adus_doc = adus[adus['essay_id'] == essay_id]

        ### WORKING 09.02.2022#$$$$$$$$$$$$
        def segmentation_error(unit, adu_start, adu_end, overlap_case, error_function):
            
            adu = unit.doc.char_span(adu_start, adu_end, alignment_mode='expand')
            
            # positive value = too many tokens in segment, unit should be shorter (include less non-adu tokens)
            # negative value = too less tokens in segment, unit should be longer (include more adu tokens)
            
            left_tokens = adu.start - unit.start
            right_tokens = unit.end - adu.end
            
            if error_function.lower() == 'percentage_correctness':
                err_func = percentage_correctness
            elif error_function.lower() == 'extended_accuracy':
                err_func = extended_accuracy

            
            return (left_tokens, err_func(unit, adu_start, adu_end, overlap_case), right_tokens)
            
# v7 returns: (ADU_Type, (left_error_tokens, err_func, right_error_tokens))
        label_and_error = [(row['ADU_type'], segmentation_error(unit, row['start_ind'],row['end_ind'], 
                          overlap_case(unit_start, unit_end,row['start_ind'], row['end_ind']), error_function),
                          #(row['start_ind'], row['end_ind'])
                           ) 
                         for row_ind, row in adus_doc.iterrows() 
                         if unit_start <= row['end_ind'] and unit_end >= row['start_ind']]

            
# v6 returns: (ADU_Type, err_func)
#
#         label_and_error = [(row['ADU_type'], err_func(unit, row['start_ind'],row['end_ind'], 
#                           overlap_case(unit_start, unit_end,row['start_ind'], row['end_ind'])),
#                           #(row['start_ind'], row['end_ind'])
#                            ) 
#                          for row_ind, row in adus_doc.iterrows() 
#                          if unit_start <= row['end_ind'] and unit_end >= row['start_ind']]

    #     # Contains information of the ADUs that overlap with the UNIT
    #     # Structure: (adu_start, adu_end, overlap_case, ADU_type)
    #     overlap_adus = [(row['start_ind'],
    #                      row['end_ind'], 
    #                      overlap_case(unit_start, unit_end,row['start_ind'], row['end_ind']), 
    #                      row['ADU_type']) 
    #                      for row_ind, row in adus_doc.iterrows()
    #           if unit_start <= row['end_ind'] and unit_end >= row['start_ind']]

        return label_and_error

    
    def get_label(span):
        
        # Gets ADU vs non-ADU LABEL for the span (intended only for sentences)

        # Works if the span is larger or equal to the adu

        # TODO:
        # DOES NOT WORK IF SPAN IS SMALLER THAN ADU, OR IF ADU IS SPLIT BETWEEN TWO SPANS (NEEDS MORE WORK!!!)
        # CLAIM VS PREMISE
        essay_id = span.doc._.essay_id

        span_start = span[0].idx
        #  + len(span[-1]) to get to the end of the last word
        span_end = span[-1].idx  + len(span[-1])
        start_inds = adus[adus['essay_id'] == essay_id ]['start_ind'].values
        end_inds = adus[adus['essay_id'] == essay_id ]['end_ind'].values

        # Checks if starting index of span is smaller than ADU and the ending index of the span is larger than the ADU
        return ((start_inds >= span_start) & (end_inds <= span_end)).any()
    
    def get_idx_start(unit):
        return unit[0].idx
    
    def get_idx_end(unit):
        return unit[-1].idx  + len(unit[-1])
    
    def get_label_pct(span):
        
        
        pass
    
    def get_para_starts(doc):
        # Units starting with \n or preceding \n are considered as paragraph starts
        # if start is 0, start -1 goes back to the last token of the doc

        # TODO
        # para_ends can be obtained by shifing this list to the right by one position
        return [int(doc[start].text =='\n' or doc[start-1].text=='\n') for start, end in doc._.units_index_list]
    
    def get_is_para_start(unit):
        
        para_starts = unit.doc._.para_starts
        unit_ind = unit._.index_in_doc
        
        return para_starts[unit_ind]
        
    
    def get_word_emb(obj):
        return obj.vector
    
    def get_num_tokens(obj):
        return len(obj)
    
    def get_num_verbs(span):
        return sum([1 for token in span if token.pos_ == "VERB"])

    def get_num_pos_pronouns(span):
        return sum([1 for token in span if token.tag_ == "PRP$"])

    def get_num_pron(span):
        return sum([1 for token in span if token.pos_ == "PRON"])
    
    def get_num_conj_adv(span):
        conj_advs = ['moreover', 'incidentally', 'next', 'yet', 'finally', 'then', 'for example', 'thus', 'accordingly', 'namely', 'meanwhile', 'that is', 'also', 'undoubtedly', 'all in all', 'lately', 'hence', 'still', 'therefore', 'in addition', 'indeed', 'again', 'so', 'nevertheless', 'besides', 'instead', 'for instance', 'certainly', 'however', 'anyway', 'further', 'furthermore', 'similarly', 'now', 'in conclusion', 'nonetheless', 'thereafter', 'likewise', 'otherwise', 'consequently']
        return sum([len(re.findall(adv, span.text.lower())) for adv in conj_advs])
    
    def get_num_punct(span):
        return sum([1 for token in span if token.tag_ == "."])
    

    def get_index_in_doc(span):
        """Gets index of the segmented unit in the doc"""
        span_start = span.start

        # span end not used yet
        span_end = span.end

        # finds where span_start is in units_index_list [(s1_start, s1_end), (s2_start, s2_end),.., (sn_start, sn_end)]
        # returns the index of the corresponding span
        return np.where([span.start in range(start, end) for start, end in span.doc._.units_index_list])[0][-1]


    def get_prev_unit(span):

        return span._.get_nth_unit(span._.index_in_doc-1)
    
        
    def get_nth_unit(span, n):

        # Tuple containing the start and end index of the nth span
        span_index = span.doc._.units_index_list[n]

        # Return nth span
        return span.doc[span_index[0]: span_index[1]]



    def get_prev_unit_attr(span, attribute):

        return span._.prev_unit._.get(attribute)
    
    

    # Iterate list of features and Set Extensions (Just to not manually set extensions one by one)
    
    for feature in extensions_dict['doc_features']:
        Doc.set_extension(feature, force=force, getter=locals()[f"get_{feature}"])
        
    for feature in extensions_dict['span_features']:
        Span.set_extension(feature, force=force, getter=locals()[f"get_{feature}"])
        
    for feature in extensions_dict['token_features']:
        Token.set_extension(feature, force=force, getter=locals()[f"get_{feature}"])
        
    for method in extensions_dict['span_methods']:
        Span.set_extension(method, force=force, method=locals()[method])


def segmentation(doc=None ,mode = 'sentence', n_grams=15):
    if mode=='paragraph':
        pass
    if mode=='sentence':
        # segment by sentences
        units = [sent for sent in doc.sents  if not (sent.text.isspace() or sent.text =='')] 
        
        # keep track of (start, end) of units in doc object
        doc._.units_index_list = [(unit.start, unit.end) for unit in units]
        return units
    
    if mode =='n_grams':
        # Code to segment with 15 grams here (average)  
        units = [doc[i:i+n_grams] for i in range(len(doc))]

        doc._.units_index_list = [(unit.start, unit.end) for unit in units]

        return units
    
    if mode=='clause':
        # Code to segment by clause
        pass
    if mode=='token':
        return [token for token in doc if not (token.text.isspace() or token.text =='')]

def unit2fv(unit, feature_list):
    
    fv = np.array([unit._.get(feature) for feature in feature_list], dtype='object')
    
    _fv = np.array([np.reshape(feature, -1) for feature in fv], dtype='object')
    
    return np.concatenate(_fv)

# Run
create_extensions(extensions_dict)

# %%
# Optional, not used yet. Trying to solve problem that title gets included with the first sentence
def add_full_stops(text):
    """adds full stops to texts that end with \n missing full stops"""
    return re.sub("\n+(?!\.)",'.\n', text)
# Not used
def text2doc(text):
    # need to use nlp.pipe here instead
    return nlp(text)

# %%
# Pipelinev1

def text2fv(df):
    data = [(row['text'], dict(id=row['essay_id'])) for ind, row in df.iterrows()]
    docs = []
    data
    for doc, context in nlp.pipe(data, as_tuples=True):
        doc._.essay_id = context['id']
        docs.append(doc)
        
    segmented_docs = [segmentation(doc, mode='sentence') for doc in docs]
    
    # Flatten lists (Dissolve docs boundaries and store all units together in one huge list)
    units = list(chain.from_iterable(segmented_docs))
    
    X_features = span_features
    

    X = np.array([unit2fv(unit, X_features) for unit in units])
    y = np.array([int(unit._.label) for unit in units])
    
    return X,y

# %%
# INPUTS 
essays = pd.read_csv("../data/output_csv/essays.csv")
adus = pd.read_csv("../data/output_csv/adus.csv")

###### TEST
in_text = essays.iloc[23].text
doc = nlp(in_text)
doc._.essay_id = essays.iloc[23]['essay_id']
adu24 = adus[adus['essay_id'] == doc._.essay_id]
units=segmentation(doc, mode='n_grams', n_grams=15)
#units=segmentation(doc, mode='sentence')

# %%
# Utility, Delete Later
def print_adus(units):
    for i, u in enumerate(units):
            unit_start = u._.idx_start
            unit_end = u._.idx_end
            
            essay_id = u.doc._.essay_id
            
            
            doc_adus = adus[adus['essay_id'] == essay_id]
             
            lis = [((unit_start, unit_end),(row['start_ind'], row['end_ind'], row['ADU_type'],is_adu(unit_start, unit_end, row['start_ind'] ,row['end_ind']))) for row_ind,row in doc_adus.iterrows() if is_adu(unit_start, unit_end, row['start_ind'] ,row['end_ind'])]
            
            
            
            if len(lis)>0:
                print(i, lis)

def verbose_print(units):
    # Detailed Printer
    
    essay_id = units[0].doc._.essay_id
    adu_doc = adus[adus['essay_id']==essay_id]
    for i, u in enumerate(units):
            span_start = u[0].idx
            span_end = u[-1].idx  + len(u[-1])

            lis = [((span_start, span_end),(row['start_ind'], row['end_ind'], row['ADU_type'],
                                            is_adu(span_start, span_end, row['start_ind'] ,row['end_ind'])))
                   for row_ind,row in adu_doc.iterrows() if is_adu(span_start, span_end, row['start_ind'] ,row['end_ind'])]
            if len(lis)>0:
                print(i)
                print(lis,"\n")
                print("UNIT:",u,"\n")
                for ind, adu in enumerate(lis):

                    #print(adu[1][2].upper()+':',adu[1][0:2])
                    #print(doc.char_span(*adu[1][0:2]), "\n")
                    label = adu[1][2].upper() 
                    adu_range = adu[1][0:2]
                    adu_status = adu[1][3]
                    print(f'ADU #{ind+1}',label+':',*adu_range, adu_status)
                    print(doc.char_span(*adu_range), "\n")
                print("-----------------\n")
                
def is_adu(unit_start, unit_end, adu_start, adu_end):
    
    if adu_start<=unit_start and adu_end <=unit_start:
        # ADU comes before UNIT
        return False
    elif adu_start>=unit_end and adu_end >=unit_end:
        # ADU comes after UNIT
        return False
    else:
        if adu_start >= unit_start and adu_end <= unit_end:
            #print("Fully Contains ADU")
            return "Full"
        elif adu_start <= unit_start and adu_end <=unit_end:
            
            #print("ADU start is cut")
            return "Start_Cut"
        elif adu_start >= unit_start and adu_end >= unit_end:
            # End of ADU is after UNIT
            return "End_Cut"

        elif adu_start <= unit_start and adu_end >= unit_end:

            # UNIT is smaller than ADU, ADU start and end are cut
            return "Both_Sides_Cut"# Utility, Delete Later

# %%
# Smaller set
essays= essays[:30].copy()

train = essays[essays['label'] =='train']
test =essays[essays['label'] =='test']

X_train, y_train = text2fv(train)

X_test, y_test = text2fv(test)

# %%
verbose_print(units)
# Out:
# 45
# [((259, 316), (311, 373, 'Claim', 'End_Cut'))]
#
# UNIT: . In my opinion, the latter opinion is true.
# First, using
#
# ADU #1 CLAIM: 311 373 End_Cut
# using computer constantly has bad influence on children's eyes
#
# -----------------
#
# 46
# [((261, 325), (311, 373, 'Claim', 'End_Cut'))]
#
# UNIT: In my opinion, the latter opinion is true.
# First, using computer
#
# ADU #1 CLAIM: 311 373 End_Cut
# using computer constantly has bad influence on children's eyes
#
# -----------------
#
# 47
# [((264, 336), (311, 373, 'Claim', 'End_Cut'))]
#
# UNIT: my opinion, the latter opinion is true.
# First, using computer constantly
#
# ADU #1 CLAIM: 311 373 End_Cut
# using computer constantly has bad influence on children's eyes
#
# -----------------
#
# 48
# [((267, 340), (311, 373, 'Claim', 'End_Cut'))]
#
# UNIT: opinion, the latter opinion is true.
# First, using computer constantly has
#
# ADU #1 CLAIM: 311 373 End_Cut
# using computer constantly has bad influence on children's eyes
#
# -----------------
#
# 49
# [((274, 344), (311, 373, 'Claim', 'End_Cut'))]
#
# UNIT: , the latter opinion is true.
# First, using computer constantly has bad
#
# ADU #1 CLAIM: 311 373 End_Cut
# using computer constantly has bad influence on children's eyes
#
# -----------------
#
# 50
# [((276, 354), (311, 373, 'Claim', 'End_Cut'))]
#
# UNIT: the latter opinion is true.
# First, using computer constantly has bad influence
#
# ADU #1 CLAIM: 311 373 End_Cut
# using computer constantly has bad influence on children's eyes
#
# -----------------
#
# 51
# [((280, 357), (311, 373, 'Claim', 'End_Cut'))]
#
# UNIT: latter opinion is true.
# First, using computer constantly has bad influence on
#
# ADU #1 CLAIM: 311 373 End_Cut
# using computer constantly has bad influence on children's eyes
#
# -----------------
#
# 52
# [((287, 366), (311, 373, 'Claim', 'End_Cut'))]
#
# UNIT: opinion is true.
# First, using computer constantly has bad influence on children
#
# ADU #1 CLAIM: 311 373 End_Cut
# using computer constantly has bad influence on children's eyes
#
# -----------------
#
# 53
# [((295, 368), (311, 373, 'Claim', 'End_Cut'))]
#
# UNIT: is true.
# First, using computer constantly has bad influence on children's
#
# ADU #1 CLAIM: 311 373 End_Cut
# using computer constantly has bad influence on children's eyes
#
# -----------------
#
# 54
# [((298, 373), (311, 373, 'Claim', 'Full'))]
#
# UNIT: true.
# First, using computer constantly has bad influence on children's eyes
#
# ADU #1 CLAIM: 311 373 Full
# using computer constantly has bad influence on children's eyes
#
# -----------------
#
# 55
# [((302, 374), (311, 373, 'Claim', 'Full'))]
#
# UNIT: .
# First, using computer constantly has bad influence on children's eyes.
#
# ADU #1 CLAIM: 311 373 Full
# using computer constantly has bad influence on children's eyes
#
# -----------------
#
# 56
# [((303, 379), (311, 373, 'Claim', 'Full')), ((303, 379), (375, 521, 'Premise', 'End_Cut'))]
#
# UNIT:
# First, using computer constantly has bad influence on children's eyes. When
#
# ADU #1 CLAIM: 311 373 Full
# using computer constantly has bad influence on children's eyes
#
# ADU #2 PREMISE: 375 521 End_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 57
# [((304, 384), (311, 373, 'Claim', 'Full')), ((304, 384), (375, 521, 'Premise', 'End_Cut'))]
#
# UNIT: First, using computer constantly has bad influence on children's eyes. When they
#
# ADU #1 CLAIM: 311 373 Full
# using computer constantly has bad influence on children's eyes
#
# ADU #2 PREMISE: 375 521 End_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 58
# [((309, 396), (311, 373, 'Claim', 'Full')), ((309, 396), (375, 521, 'Premise', 'End_Cut'))]
#
# UNIT: , using computer constantly has bad influence on children's eyes. When they concentrate
#
# ADU #1 CLAIM: 311 373 Full
# using computer constantly has bad influence on children's eyes
#
# ADU #2 PREMISE: 375 521 End_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 59
# [((311, 399), (311, 373, 'Claim', 'Full')), ((311, 399), (375, 521, 'Premise', 'End_Cut'))]
#
# UNIT: using computer constantly has bad influence on children's eyes. When they concentrate on
#
# ADU #1 CLAIM: 311 373 Full
# using computer constantly has bad influence on children's eyes
#
# ADU #2 PREMISE: 375 521 End_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 60
# [((317, 408), (311, 373, 'Claim', 'Start_Cut')), ((317, 408), (375, 521, 'Premise', 'End_Cut'))]
#
# UNIT: computer constantly has bad influence on children's eyes. When they concentrate on computer
#
# ADU #1 CLAIM: 311 373 Start_Cut
# using computer constantly has bad influence on children's eyes
#
# ADU #2 PREMISE: 375 521 End_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 61
# [((326, 412), (311, 373, 'Claim', 'Start_Cut')), ((326, 412), (375, 521, 'Premise', 'End_Cut'))]
#
# UNIT: constantly has bad influence on children's eyes. When they concentrate on computer for
#
# ADU #1 CLAIM: 311 373 Start_Cut
# using computer constantly has bad influence on children's eyes
#
# ADU #2 PREMISE: 375 521 End_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 62
# [((337, 416), (311, 373, 'Claim', 'Start_Cut')), ((337, 416), (375, 521, 'Premise', 'End_Cut'))]
#
# UNIT: has bad influence on children's eyes. When they concentrate on computer for too
#
# ADU #1 CLAIM: 311 373 Start_Cut
# using computer constantly has bad influence on children's eyes
#
# ADU #2 PREMISE: 375 521 End_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 63
# [((341, 421), (311, 373, 'Claim', 'Start_Cut')), ((341, 421), (375, 521, 'Premise', 'End_Cut'))]
#
# UNIT: bad influence on children's eyes. When they concentrate on computer for too long
#
# ADU #1 CLAIM: 311 373 Start_Cut
# using computer constantly has bad influence on children's eyes
#
# ADU #2 PREMISE: 375 521 End_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 64
# [((345, 422), (311, 373, 'Claim', 'Start_Cut')), ((345, 422), (375, 521, 'Premise', 'End_Cut'))]
#
# UNIT: influence on children's eyes. When they concentrate on computer for too long,
#
# ADU #1 CLAIM: 311 373 Start_Cut
# using computer constantly has bad influence on children's eyes
#
# ADU #2 PREMISE: 375 521 End_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 65
# [((355, 428), (311, 373, 'Claim', 'Start_Cut')), ((355, 428), (375, 521, 'Premise', 'End_Cut'))]
#
# UNIT: on children's eyes. When they concentrate on computer for too long, their
#
# ADU #1 CLAIM: 311 373 Start_Cut
# using computer constantly has bad influence on children's eyes
#
# ADU #2 PREMISE: 375 521 End_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 66
# [((358, 433), (311, 373, 'Claim', 'Start_Cut')), ((358, 433), (375, 521, 'Premise', 'End_Cut'))]
#
# UNIT: children's eyes. When they concentrate on computer for too long, their eyes
#
# ADU #1 CLAIM: 311 373 Start_Cut
# using computer constantly has bad influence on children's eyes
#
# ADU #2 PREMISE: 375 521 End_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 67
# [((366, 438), (311, 373, 'Claim', 'Start_Cut')), ((366, 438), (375, 521, 'Premise', 'End_Cut'))]
#
# UNIT: 's eyes. When they concentrate on computer for too long, their eyes will
#
# ADU #1 CLAIM: 311 373 Start_Cut
# using computer constantly has bad influence on children's eyes
#
# ADU #2 PREMISE: 375 521 End_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 68
# [((369, 442), (311, 373, 'Claim', 'Start_Cut')), ((369, 442), (375, 521, 'Premise', 'End_Cut'))]
#
# UNIT: eyes. When they concentrate on computer for too long, their eyes will get
#
# ADU #1 CLAIM: 311 373 Start_Cut
# using computer constantly has bad influence on children's eyes
#
# ADU #2 PREMISE: 375 521 End_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 69
# [((373, 448), (375, 521, 'Premise', 'End_Cut'))]
#
# UNIT: . When they concentrate on computer for too long, their eyes will get tired
#
# ADU #1 PREMISE: 375 521 End_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 70
# [((375, 449), (375, 521, 'Premise', 'End_Cut'))]
#
# UNIT: When they concentrate on computer for too long, their eyes will get tired,
#
# ADU #1 PREMISE: 375 521 End_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 71
# [((380, 455), (375, 521, 'Premise', 'Both_Sides_Cut'))]
#
# UNIT: they concentrate on computer for too long, their eyes will get tired, which
#
# ADU #1 PREMISE: 375 521 Both_Sides_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 72
# [((385, 458), (375, 521, 'Premise', 'Both_Sides_Cut'))]
#
# UNIT: concentrate on computer for too long, their eyes will get tired, which is
#
# ADU #1 PREMISE: 375 521 Both_Sides_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 73
# [((397, 462), (375, 521, 'Premise', 'Both_Sides_Cut'))]
#
# UNIT: on computer for too long, their eyes will get tired, which is the
#
# ADU #1 PREMISE: 375 521 Both_Sides_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 74
# [((400, 467), (375, 521, 'Premise', 'Both_Sides_Cut'))]
#
# UNIT: computer for too long, their eyes will get tired, which is the main
#
# ADU #1 PREMISE: 375 521 Both_Sides_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 75
# [((409, 474), (375, 521, 'Premise', 'Both_Sides_Cut'))]
#
# UNIT: for too long, their eyes will get tired, which is the main reason
#
# ADU #1 PREMISE: 375 521 Both_Sides_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 76
# [((413, 478), (375, 521, 'Premise', 'Both_Sides_Cut'))]
#
# UNIT: too long, their eyes will get tired, which is the main reason for
#
# ADU #1 PREMISE: 375 521 Both_Sides_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 77
# [((417, 483), (375, 521, 'Premise', 'Both_Sides_Cut'))]
#
# UNIT: long, their eyes will get tired, which is the main reason for some
#
# ADU #1 PREMISE: 375 521 Both_Sides_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 78
# [((421, 488), (375, 521, 'Premise', 'Both_Sides_Cut'))]
#
# UNIT: , their eyes will get tired, which is the main reason for some eyes
#
# ADU #1 PREMISE: 375 521 Both_Sides_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 79
# [((423, 497), (375, 521, 'Premise', 'Both_Sides_Cut'))]
#
# UNIT: their eyes will get tired, which is the main reason for some eyes problems
#
# ADU #1 PREMISE: 375 521 Both_Sides_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 80
# [((429, 498), (375, 521, 'Premise', 'Both_Sides_Cut'))]
#
# UNIT: eyes will get tired, which is the main reason for some eyes problems,
#
# ADU #1 PREMISE: 375 521 Both_Sides_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 81
# [((434, 508), (375, 521, 'Premise', 'Both_Sides_Cut'))]
#
# UNIT: will get tired, which is the main reason for some eyes problems, typically
#
# ADU #1 PREMISE: 375 521 Both_Sides_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 82
# [((439, 521), (375, 521, 'Premise', 'Start_Cut'))]
#
# UNIT: get tired, which is the main reason for some eyes problems, typically shortsighted
#
# ADU #1 PREMISE: 375 521 Start_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 83
# [((443, 522), (375, 521, 'Premise', 'Start_Cut'))]
#
# UNIT: tired, which is the main reason for some eyes problems, typically shortsighted.
#
# ADU #1 PREMISE: 375 521 Start_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 84
# [((448, 523), (375, 521, 'Premise', 'Start_Cut'))]
#
# UNIT: , which is the main reason for some eyes problems, typically shortsighted.
#
#
# ADU #1 PREMISE: 375 521 Start_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 85
# [((450, 531), (375, 521, 'Premise', 'Start_Cut'))]
#
# UNIT: which is the main reason for some eyes problems, typically shortsighted.
# Moreover
#
# ADU #1 PREMISE: 375 521 Start_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 86
# [((456, 532), (375, 521, 'Premise', 'Start_Cut'))]
#
# UNIT: is the main reason for some eyes problems, typically shortsighted.
# Moreover,
#
# ADU #1 PREMISE: 375 521 Start_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# -----------------
#
# 87
# [((459, 541), (375, 521, 'Premise', 'Start_Cut')), ((459, 541), (533, 617, 'Premise', 'End_Cut'))]
#
# UNIT: the main reason for some eyes problems, typically shortsighted.
# Moreover, children
#
# ADU #1 PREMISE: 375 521 Start_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# ADU #2 PREMISE: 533 617 End_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# -----------------
#
# 88
# [((463, 545), (375, 521, 'Premise', 'Start_Cut')), ((463, 545), (533, 617, 'Premise', 'End_Cut'))]
#
# UNIT: main reason for some eyes problems, typically shortsighted.
# Moreover, children who
#
# ADU #1 PREMISE: 375 521 Start_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# ADU #2 PREMISE: 533 617 End_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# -----------------
#
# 89
# [((468, 550), (375, 521, 'Premise', 'Start_Cut')), ((468, 550), (533, 617, 'Premise', 'End_Cut'))]
#
# UNIT: reason for some eyes problems, typically shortsighted.
# Moreover, children who play
#
# ADU #1 PREMISE: 375 521 Start_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# ADU #2 PREMISE: 533 617 End_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# -----------------
#
# 90
# [((475, 556), (375, 521, 'Premise', 'Start_Cut')), ((475, 556), (533, 617, 'Premise', 'End_Cut'))]
#
# UNIT: for some eyes problems, typically shortsighted.
# Moreover, children who play games
#
# ADU #1 PREMISE: 375 521 Start_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# ADU #2 PREMISE: 533 617 End_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# -----------------
#
# 91
# [((479, 560), (375, 521, 'Premise', 'Start_Cut')), ((479, 560), (533, 617, 'Premise', 'End_Cut'))]
#
# UNIT: some eyes problems, typically shortsighted.
# Moreover, children who play games too
#
# ADU #1 PREMISE: 375 521 Start_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# ADU #2 PREMISE: 533 617 End_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# -----------------
#
# 92
# [((484, 565), (375, 521, 'Premise', 'Start_Cut')), ((484, 565), (533, 617, 'Premise', 'End_Cut'))]
#
# UNIT: eyes problems, typically shortsighted.
# Moreover, children who play games too much
#
# ADU #1 PREMISE: 375 521 Start_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# ADU #2 PREMISE: 533 617 End_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# -----------------
#
# 93
# [((489, 568), (375, 521, 'Premise', 'Start_Cut')), ((489, 568), (533, 617, 'Premise', 'End_Cut'))]
#
# UNIT: problems, typically shortsighted.
# Moreover, children who play games too much on
#
# ADU #1 PREMISE: 375 521 Start_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# ADU #2 PREMISE: 533 617 End_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# -----------------
#
# 94
# [((497, 577), (375, 521, 'Premise', 'Start_Cut')), ((497, 577), (533, 617, 'Premise', 'End_Cut'))]
#
# UNIT: , typically shortsighted.
# Moreover, children who play games too much on computer
#
# ADU #1 PREMISE: 375 521 Start_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# ADU #2 PREMISE: 533 617 End_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# -----------------
#
# 95
# [((499, 581), (375, 521, 'Premise', 'Start_Cut')), ((499, 581), (533, 617, 'Premise', 'End_Cut'))]
#
# UNIT: typically shortsighted.
# Moreover, children who play games too much on computer can
#
# ADU #1 PREMISE: 375 521 Start_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# ADU #2 PREMISE: 533 617 End_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# -----------------
#
# 96
# [((509, 591), (375, 521, 'Premise', 'Start_Cut')), ((509, 591), (533, 617, 'Premise', 'End_Cut'))]
#
# UNIT: shortsighted.
# Moreover, children who play games too much on computer can seriously
#
# ADU #1 PREMISE: 375 521 Start_Cut
# When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted
#
# ADU #2 PREMISE: 533 617 End_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# -----------------
#
# 97
# [((521, 596), (533, 617, 'Premise', 'End_Cut'))]
#
# UNIT: .
# Moreover, children who play games too much on computer can seriously lack
#
# ADU #1 PREMISE: 533 617 End_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# -----------------
#
# 98
# [((522, 610), (533, 617, 'Premise', 'End_Cut'))]
#
# UNIT:
# Moreover, children who play games too much on computer can seriously lack communicating
#
# ADU #1 PREMISE: 533 617 End_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# -----------------
#
# 99
# [((523, 617), (533, 617, 'Premise', 'Full'))]
#
# UNIT: Moreover, children who play games too much on computer can seriously lack communicating skills
#
# ADU #1 PREMISE: 533 617 Full
# children who play games too much on computer can seriously lack communicating skills
#
# -----------------
#
# 100
# [((531, 618), (533, 617, 'Premise', 'Full'))]
#
# UNIT: , children who play games too much on computer can seriously lack communicating skills,
#
# ADU #1 PREMISE: 533 617 Full
# children who play games too much on computer can seriously lack communicating skills
#
# -----------------
#
# 101
# [((533, 623), (533, 617, 'Premise', 'Full')), ((533, 623), (619, 663, 'Premise', 'End_Cut'))]
#
# UNIT: children who play games too much on computer can seriously lack communicating skills, they
#
# ADU #1 PREMISE: 533 617 Full
# children who play games too much on computer can seriously lack communicating skills
#
# ADU #2 PREMISE: 619 663 End_Cut
# they will know little about the outside life
#
# -----------------
#
# 102
# [((542, 628), (533, 617, 'Premise', 'Start_Cut')), ((542, 628), (619, 663, 'Premise', 'End_Cut'))]
#
# UNIT: who play games too much on computer can seriously lack communicating skills, they will
#
# ADU #1 PREMISE: 533 617 Start_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# ADU #2 PREMISE: 619 663 End_Cut
# they will know little about the outside life
#
# -----------------
#
# 103
# [((546, 633), (533, 617, 'Premise', 'Start_Cut')), ((546, 633), (619, 663, 'Premise', 'End_Cut'))]
#
# UNIT: play games too much on computer can seriously lack communicating skills, they will know
#
# ADU #1 PREMISE: 533 617 Start_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# ADU #2 PREMISE: 619 663 End_Cut
# they will know little about the outside life
#
# -----------------
#
# 104
# [((551, 640), (533, 617, 'Premise', 'Start_Cut')), ((551, 640), (619, 663, 'Premise', 'End_Cut'))]
#
# UNIT: games too much on computer can seriously lack communicating skills, they will know little
#
# ADU #1 PREMISE: 533 617 Start_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# ADU #2 PREMISE: 619 663 End_Cut
# they will know little about the outside life
#
# -----------------
#
# 105
# [((557, 646), (533, 617, 'Premise', 'Start_Cut')), ((557, 646), (619, 663, 'Premise', 'End_Cut'))]
#
# UNIT: too much on computer can seriously lack communicating skills, they will know little about
#
# ADU #1 PREMISE: 533 617 Start_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# ADU #2 PREMISE: 619 663 End_Cut
# they will know little about the outside life
#
# -----------------
#
# 106
# [((561, 650), (533, 617, 'Premise', 'Start_Cut')), ((561, 650), (619, 663, 'Premise', 'End_Cut'))]
#
# UNIT: much on computer can seriously lack communicating skills, they will know little about the
#
# ADU #1 PREMISE: 533 617 Start_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# ADU #2 PREMISE: 619 663 End_Cut
# they will know little about the outside life
#
# -----------------
#
# 107
# [((566, 658), (533, 617, 'Premise', 'Start_Cut')), ((566, 658), (619, 663, 'Premise', 'End_Cut'))]
#
# UNIT: on computer can seriously lack communicating skills, they will know little about the outside
#
# ADU #1 PREMISE: 533 617 Start_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# ADU #2 PREMISE: 619 663 End_Cut
# they will know little about the outside life
#
# -----------------
#
# 108
# [((569, 663), (533, 617, 'Premise', 'Start_Cut')), ((569, 663), (619, 663, 'Premise', 'Full'))]
#
# UNIT: computer can seriously lack communicating skills, they will know little about the outside life
#
# ADU #1 PREMISE: 533 617 Start_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# ADU #2 PREMISE: 619 663 Full
# they will know little about the outside life
#
# -----------------
#
# 109
# [((578, 664), (533, 617, 'Premise', 'Start_Cut')), ((578, 664), (619, 663, 'Premise', 'Full'))]
#
# UNIT: can seriously lack communicating skills, they will know little about the outside life.
#
# ADU #1 PREMISE: 533 617 Start_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# ADU #2 PREMISE: 619 663 Full
# they will know little about the outside life
#
# -----------------
#
# 110
# [((582, 667), (533, 617, 'Premise', 'Start_Cut')), ((582, 667), (619, 663, 'Premise', 'Full'))]
#
# UNIT: seriously lack communicating skills, they will know little about the outside life. It
#
# ADU #1 PREMISE: 533 617 Start_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# ADU #2 PREMISE: 619 663 Full
# they will know little about the outside life
#
# -----------------
#
# 111
# [((592, 670), (533, 617, 'Premise', 'Start_Cut')), ((592, 670), (619, 663, 'Premise', 'Full'))]
#
# UNIT: lack communicating skills, they will know little about the outside life. It is
#
# ADU #1 PREMISE: 533 617 Start_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# ADU #2 PREMISE: 619 663 Full
# they will know little about the outside life
#
# -----------------
#
# 112
# [((597, 672), (533, 617, 'Premise', 'Start_Cut')), ((597, 672), (619, 663, 'Premise', 'Full'))]
#
# UNIT: communicating skills, they will know little about the outside life. It is a
#
# ADU #1 PREMISE: 533 617 Start_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# ADU #2 PREMISE: 619 663 Full
# they will know little about the outside life
#
# -----------------
#
# 113
# [((611, 677), (533, 617, 'Premise', 'Start_Cut')), ((611, 677), (619, 663, 'Premise', 'Full'))]
#
# UNIT: skills, they will know little about the outside life. It is a well
#
# ADU #1 PREMISE: 533 617 Start_Cut
# children who play games too much on computer can seriously lack communicating skills
#
# ADU #2 PREMISE: 619 663 Full
# they will know little about the outside life
#
# -----------------
#
# 114
# [((617, 678), (619, 663, 'Premise', 'Full'))]
#
# UNIT: , they will know little about the outside life. It is a well-
#
# ADU #1 PREMISE: 619 663 Full
# they will know little about the outside life
#
# -----------------
#
# 115
# [((619, 683), (619, 663, 'Premise', 'Full'))]
#
# UNIT: they will know little about the outside life. It is a well-known
#
# ADU #1 PREMISE: 619 663 Full
# they will know little about the outside life
#
# -----------------
#
# 116
# [((624, 688), (619, 663, 'Premise', 'Start_Cut'))]
#
# UNIT: will know little about the outside life. It is a well-known fact
#
# ADU #1 PREMISE: 619 663 Start_Cut
# they will know little about the outside life
#
# -----------------
#
# 117
# [((629, 693), (619, 663, 'Premise', 'Start_Cut'))]
#
# UNIT: know little about the outside life. It is a well-known fact that
#
# ADU #1 PREMISE: 619 663 Start_Cut
# they will know little about the outside life
#
# -----------------
#
# 118
# [((634, 700), (694, 795, 'Claim', 'End_Cut')), ((634, 700), (619, 663, 'Premise', 'Start_Cut'))]
#
# UNIT: little about the outside life. It is a well-known fact that people
#
# ADU #1 CLAIM: 694 795 End_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# ADU #2 PREMISE: 619 663 Start_Cut
# they will know little about the outside life
#
# -----------------
#
# 119
# [((641, 704), (694, 795, 'Claim', 'End_Cut')), ((641, 704), (619, 663, 'Premise', 'Start_Cut'))]
#
# UNIT: about the outside life. It is a well-known fact that people who
#
# ADU #1 CLAIM: 694 795 End_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# ADU #2 PREMISE: 619 663 Start_Cut
# they will know little about the outside life
#
# -----------------
#
# 120
# [((647, 708), (694, 795, 'Claim', 'End_Cut')), ((647, 708), (619, 663, 'Premise', 'Start_Cut'))]
#
# UNIT: the outside life. It is a well-known fact that people who are
#
# ADU #1 CLAIM: 694 795 End_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# ADU #2 PREMISE: 619 663 Start_Cut
# they will know little about the outside life
#
# -----------------
#
# 121
# [((651, 717), (694, 795, 'Claim', 'End_Cut')), ((651, 717), (619, 663, 'Premise', 'Start_Cut'))]
#
# UNIT: outside life. It is a well-known fact that people who are addicted
#
# ADU #1 CLAIM: 694 795 End_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# ADU #2 PREMISE: 619 663 Start_Cut
# they will know little about the outside life
#
# -----------------
#
# 122
# [((659, 720), (694, 795, 'Claim', 'End_Cut')), ((659, 720), (619, 663, 'Premise', 'Start_Cut'))]
#
# UNIT: life. It is a well-known fact that people who are addicted to
#
# ADU #1 CLAIM: 694 795 End_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# ADU #2 PREMISE: 619 663 Start_Cut
# they will know little about the outside life
#
# -----------------
#
# 123
# [((663, 726), (694, 795, 'Claim', 'End_Cut'))]
#
# UNIT: . It is a well-known fact that people who are addicted to games
#
# ADU #1 CLAIM: 694 795 End_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# -----------------
#
# 124
# [((665, 727), (694, 795, 'Claim', 'End_Cut'))]
#
# UNIT: It is a well-known fact that people who are addicted to games,
#
# ADU #1 CLAIM: 694 795 End_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# -----------------
#
# 125
# [((668, 738), (694, 795, 'Claim', 'End_Cut'))]
#
# UNIT: is a well-known fact that people who are addicted to games, especially
#
# ADU #1 CLAIM: 694 795 End_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# -----------------
#
# 126
# [((671, 745), (694, 795, 'Claim', 'End_Cut'))]
#
# UNIT: a well-known fact that people who are addicted to games, especially online
#
# ADU #1 CLAIM: 694 795 End_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# -----------------
#
# 127
# [((673, 751), (694, 795, 'Claim', 'End_Cut'))]
#
# UNIT: well-known fact that people who are addicted to games, especially online games
#
# ADU #1 CLAIM: 694 795 End_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# -----------------
#
# 128
# [((677, 752), (694, 795, 'Claim', 'End_Cut'))]
#
# UNIT: -known fact that people who are addicted to games, especially online games,
#
# ADU #1 CLAIM: 694 795 End_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# -----------------
#
# 129
# [((678, 756), (694, 795, 'Claim', 'End_Cut'))]
#
# UNIT: known fact that people who are addicted to games, especially online games, can
#
# ADU #1 CLAIM: 694 795 End_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# -----------------
# 130
# [((684, 767), (694, 795, 'Claim', 'End_Cut'))]
#
# UNIT: fact that people who are addicted to games, especially online games, can eventually
#
# ADU #1 CLAIM: 694 795 End_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# -----------------
#
# 131
# [((689, 772), (694, 795, 'Claim', 'End_Cut'))]
#
# UNIT: that people who are addicted to games, especially online games, can eventually bear
#
# ADU #1 CLAIM: 694 795 End_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# -----------------
#
# 132
# [((694, 782), (694, 795, 'Claim', 'End_Cut'))]
#
# UNIT: people who are addicted to games, especially online games, can eventually bear dangerous
#
# ADU #1 CLAIM: 694 795 End_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# -----------------
#
# 133
# [((701, 795), (694, 795, 'Claim', 'Start_Cut'))]
#
# UNIT: who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# ADU #1 CLAIM: 694 795 Start_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# -----------------
#
# 134
# [((705, 796), (694, 795, 'Claim', 'Start_Cut'))]
#
# UNIT: are addicted to games, especially online games, can eventually bear dangerous consequences.
#
# ADU #1 CLAIM: 694 795 Start_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# -----------------
#
# 135
# [((709, 800), (694, 795, 'Claim', 'Start_Cut'))]
#
# UNIT: addicted to games, especially online games, can eventually bear dangerous consequences. For
#
# ADU #1 CLAIM: 694 795 Start_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# -----------------
#
# 136
# [((718, 809), (694, 795, 'Claim', 'Start_Cut'))]
#
# UNIT: to games, especially online games, can eventually bear dangerous consequences. For instance
#
# ADU #1 CLAIM: 694 795 Start_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# -----------------
#
# 137
# [((721, 810), (694, 795, 'Claim', 'Start_Cut'))]
#
# UNIT: games, especially online games, can eventually bear dangerous consequences. For instance,
#
# ADU #1 CLAIM: 694 795 Start_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# -----------------
#
# 138
# [((726, 818), (694, 795, 'Claim', 'Start_Cut')), ((726, 818), (811, 886, 'Premise', 'End_Cut'))]
#
# UNIT: , especially online games, can eventually bear dangerous consequences. For instance, several
#
# ADU #1 CLAIM: 694 795 Start_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# ADU #2 PREMISE: 811 886 End_Cut
# several teenagers play games without rest, which leads to health depression
#
# -----------------
#
# 139
# [((728, 828), (694, 795, 'Claim', 'Start_Cut')), ((728, 828), (811, 886, 'Premise', 'End_Cut'))]
#
# UNIT: especially online games, can eventually bear dangerous consequences. For instance, several teenagers
#
# ADU #1 CLAIM: 694 795 Start_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# ADU #2 PREMISE: 811 886 End_Cut
# several teenagers play games without rest, which leads to health depression
#
# -----------------
#
# 140
# [((739, 833), (694, 795, 'Claim', 'Start_Cut')), ((739, 833), (811, 886, 'Premise', 'End_Cut'))]
#
# UNIT: online games, can eventually bear dangerous consequences. For instance, several teenagers play
#
# ADU #1 CLAIM: 694 795 Start_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# ADU #2 PREMISE: 811 886 End_Cut
# several teenagers play games without rest, which leads to health depression
#
# -----------------
#
# 141
# [((746, 839), (694, 795, 'Claim', 'Start_Cut')), ((746, 839), (811, 886, 'Premise', 'End_Cut'))]
#
# UNIT: games, can eventually bear dangerous consequences. For instance, several teenagers play games
#
# ADU #1 CLAIM: 694 795 Start_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# ADU #2 PREMISE: 811 886 End_Cut
# several teenagers play games without rest, which leads to health depression
#
# -----------------
#
# 142
# [((751, 847), (694, 795, 'Claim', 'Start_Cut')), ((751, 847), (811, 886, 'Premise', 'End_Cut'))]
#
# UNIT: , can eventually bear dangerous consequences. For instance, several teenagers play games without
#
# ADU #1 CLAIM: 694 795 Start_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# ADU #2 PREMISE: 811 886 End_Cut
# several teenagers play games without rest, which leads to health depression
#
# -----------------
#
# 143
# [((753, 852), (694, 795, 'Claim', 'Start_Cut')), ((753, 852), (811, 886, 'Premise', 'End_Cut'))]
#
# UNIT: can eventually bear dangerous consequences. For instance, several teenagers play games without rest
#
# ADU #1 CLAIM: 694 795 Start_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# ADU #2 PREMISE: 811 886 End_Cut
# several teenagers play games without rest, which leads to health depression
#
# -----------------
#
# 144
# [((757, 853), (694, 795, 'Claim', 'Start_Cut')), ((757, 853), (811, 886, 'Premise', 'End_Cut'))]
#
# UNIT: eventually bear dangerous consequences. For instance, several teenagers play games without rest,
#
# ADU #1 CLAIM: 694 795 Start_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# ADU #2 PREMISE: 811 886 End_Cut
# several teenagers play games without rest, which leads to health depression
#
# -----------------
#
# 145
# [((768, 859), (694, 795, 'Claim', 'Start_Cut')), ((768, 859), (811, 886, 'Premise', 'End_Cut'))]
#
# UNIT: bear dangerous consequences. For instance, several teenagers play games without rest, which
#
# ADU #1 CLAIM: 694 795 Start_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# ADU #2 PREMISE: 811 886 End_Cut
# several teenagers play games without rest, which leads to health depression
#
# -----------------
#
# 146
# [((773, 865), (694, 795, 'Claim', 'Start_Cut')), ((773, 865), (811, 886, 'Premise', 'End_Cut'))]
#
# UNIT: dangerous consequences. For instance, several teenagers play games without rest, which leads
#
# ADU #1 CLAIM: 694 795 Start_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# ADU #2 PREMISE: 811 886 End_Cut
# several teenagers play games without rest, which leads to health depression
#
# -----------------
#
# 147
# [((783, 868), (694, 795, 'Claim', 'Start_Cut')), ((783, 868), (811, 886, 'Premise', 'End_Cut'))]
#
# UNIT: consequences. For instance, several teenagers play games without rest, which leads to
#
# ADU #1 CLAIM: 694 795 Start_Cut
# people who are addicted to games, especially online games, can eventually bear dangerous consequences
#
# ADU #2 PREMISE: 811 886 End_Cut
# several teenagers play games without rest, which leads to health depression
#
# -----------------
#
# 148
# [((795, 875), (811, 886, 'Premise', 'End_Cut'))]
#
# UNIT: . For instance, several teenagers play games without rest, which leads to health
#
# ADU #1 PREMISE: 811 886 End_Cut
# several teenagers play games without rest, which leads to health depression
#
# -----------------
#
# 149
# [((797, 886), (811, 886, 'Premise', 'Full'))]
#
# UNIT: For instance, several teenagers play games without rest, which leads to health depression
#
# ADU #1 PREMISE: 811 886 Full
# several teenagers play games without rest, which leads to health depression
#
# -----------------
#
# 150
# [((801, 887), (811, 886, 'Premise', 'Full'))]
#
# UNIT: instance, several teenagers play games without rest, which leads to health depression,
#
# ADU #1 PREMISE: 811 886 Full
# several teenagers play games without rest, which leads to health depression
#
# -----------------
#
# 151
# [((809, 889), (811, 886, 'Premise', 'Full')), ((809, 889), (888, 973, 'Premise', 'End_Cut'))]
#
# UNIT: , several teenagers play games without rest, which leads to health depression, a
#
# ADU #1 PREMISE: 811 886 Full
# several teenagers play games without rest, which leads to health depression
#
# ADU #2 PREMISE: 888 973 End_Cut
# a typical example is the death of Korean gamer, who had a non-stop playing for 3 days
#
# -----------------
#
# 152
# [((811, 897), (811, 886, 'Premise', 'Full')), ((811, 897), (888, 973, 'Premise', 'End_Cut'))]
#
# UNIT: several teenagers play games without rest, which leads to health depression, a typical
#
# ADU #1 PREMISE: 811 886 Full
# several teenagers play games without rest, which leads to health depression
#
# ADU #2 PREMISE: 888 973 End_Cut
# a typical example is the death of Korean gamer, who had a non-stop playing for 3 days
#
# -----------------
#
# 153
# [((819, 905), (811, 886, 'Premise', 'Start_Cut')), ((819, 905), (888, 973, 'Premise', 'End_Cut'))]
#
# UNIT: teenagers play games without rest, which leads to health depression, a typical example
#
# ADU #1 PREMISE: 811 886 Start_Cut
# several teenagers play games without rest, which leads to health depression
#
# ADU #2 PREMISE: 888 973 End_Cut
# a typical example is the death of Korean gamer, who had a non-stop playing for 3 days
#
# -----------------
#
# 154
# [((829, 908), (811, 886, 'Premise', 'Start_Cut')), ((829, 908), (888, 973, 'Premise', 'End_Cut'))]
#
# UNIT: play games without rest, which leads to health depression, a typical example is
#
# ADU #1 PREMISE: 811 886 Start_Cut
# several teenagers play games without rest, which leads to health depression
#
# ADU #2 PREMISE: 888 973 End_Cut
# a typical example is the death of Korean gamer, who had a non-stop playing for 3 days
#
# -----------------
#
# 155
# [((834, 912), (811, 886, 'Premise', 'Start_Cut')), ((834, 912), (888, 973, 'Premise', 'End_Cut'))]
#
# UNIT: games without rest, which leads to health depression, a typical example is the
#
# ADU #1 PREMISE: 811 886 Start_Cut
# several teenagers play games without rest, which leads to health depression
#
# ADU #2 PREMISE: 888 973 End_Cut
# a typical example is the death of Korean gamer, who had a non-stop playing for 3 days
#
# -----------------
#
# 156
# [((840, 918), (811, 886, 'Premise', 'Start_Cut')), ((840, 918), (888, 973, 'Premise', 'End_Cut'))]
#
# UNIT: without rest, which leads to health depression, a typical example is the death
#
# ADU #1 PREMISE: 811 886 Start_Cut
# several teenagers play games without rest, which leads to health depression
#
# ADU #2 PREMISE: 888 973 End_Cut
# a typical example is the death of Korean gamer, who had a non-stop playing for 3 days
#
# -----------------
#
# 157
# [((848, 921), (811, 886, 'Premise', 'Start_Cut')), ((848, 921), (888, 973, 'Premise', 'End_Cut'))]
#
# UNIT: rest, which leads to health depression, a typical example is the death of
#
# ADU #1 PREMISE: 811 886 Start_Cut
# several teenagers play games without rest, which leads to health depression
#
# ADU #2 PREMISE: 888 973 End_Cut
# a typical example is the death of Korean gamer, who had a non-stop playing for 3 days
#
# -----------------
#
# 158
# [((852, 928), (811, 886, 'Premise', 'Start_Cut')), ((852, 928), (888, 973, 'Premise', 'End_Cut'))]
#
# UNIT: , which leads to health depression, a typical example is the death of Korean
#
# ADU #1 PREMISE: 811 886 Start_Cut
# several teenagers play games without rest, which leads to health depression
#
# ADU #2 PREMISE: 888 973 End_Cut
# a typical example is the death of Korean gamer, who had a non-stop playing for 3 days
#
# -----------------
#
# 159
# [((854, 934), (811, 886, 'Premise', 'Start_Cut')), ((854, 934), (888, 973, 'Premise', 'End_Cut'))]
#
# UNIT: which leads to health depression, a typical example is the death of Korean gamer
#
# ADU #1 PREMISE: 811 886 Start_Cut
# several teenagers play games without rest, which leads to health depression
#
# ADU #2 PREMISE: 888 973 End_Cut
# a typical example is the death of Korean gamer, who had a non-stop playing for 3 days
#
# -----------------
#
# 160
# [((860, 935), (811, 886, 'Premise', 'Start_Cut')), ((860, 935), (888, 973, 'Premise', 'End_Cut'))]
#
# UNIT: leads to health depression, a typical example is the death of Korean gamer,
#
# ADU #1 PREMISE: 811 886 Start_Cut
# several teenagers play games without rest, which leads to health depression
#
# ADU #2 PREMISE: 888 973 End_Cut
# a typical example is the death of Korean gamer, who had a non-stop playing for 3 days
#
# -----------------
#
# 161
# [((866, 939), (811, 886, 'Premise', 'Start_Cut')), ((866, 939), (888, 973, 'Premise', 'End_Cut'))]
#
# UNIT: to health depression, a typical example is the death of Korean gamer, who
#
# ADU #1 PREMISE: 811 886 Start_Cut
# several teenagers play games without rest, which leads to health depression
#
# ADU #2 PREMISE: 888 973 End_Cut
# a typical example is the death of Korean gamer, who had a non-stop playing for 3 days
#
# -----------------
#
# 162
# [((869, 943), (811, 886, 'Premise', 'Start_Cut')), ((869, 943), (888, 973, 'Premise', 'End_Cut'))]
#
# UNIT: health depression, a typical example is the death of Korean gamer, who had
#
# ADU #1 PREMISE: 811 886 Start_Cut
# several teenagers play games without rest, which leads to health depression
#
# ADU #2 PREMISE: 888 973 End_Cut
# a typical example is the death of Korean gamer, who had a non-stop playing for 3 days
#
# -----------------
#
# 163
# [((876, 945), (811, 886, 'Premise', 'Start_Cut')), ((876, 945), (888, 973, 'Premise', 'End_Cut'))]
#
# UNIT: depression, a typical example is the death of Korean gamer, who had a
#
# ADU #1 PREMISE: 811 886 Start_Cut
# several teenagers play games without rest, which leads to health depression
#
# ADU #2 PREMISE: 888 973 End_Cut
# a typical example is the death of Korean gamer, who had a non-stop playing for 3 days
#
# -----------------
#
# 164
# [((886, 949), (888, 973, 'Premise', 'End_Cut'))]
#
# UNIT: , a typical example is the death of Korean gamer, who had a non
#
# ADU #1 PREMISE: 888 973 End_Cut
# a typical example is the death of Korean gamer, who had a non-stop playing for 3 days
#
# -----------------
#
# 165
# [((888, 950), (888, 973, 'Premise', 'End_Cut'))]
#
# UNIT: a typical example is the death of Korean gamer, who had a non-
#
# ADU #1 PREMISE: 888 973 End_Cut
# a typical example is the death of Korean gamer, who had a non-stop playing for 3 days
#
# -----------------
#
# 166
# [((890, 954), (888, 973, 'Premise', 'Both_Sides_Cut'))]
#
# UNIT: typical example is the death of Korean gamer, who had a non-stop
#
# ADU #1 PREMISE: 888 973 Both_Sides_Cut
# a typical example is the death of Korean gamer, who had a non-stop playing for 3 days
#
# -----------------
#
# 167
# [((898, 962), (888, 973, 'Premise', 'Both_Sides_Cut'))]
#
# UNIT: example is the death of Korean gamer, who had a non-stop playing
#
# ADU #1 PREMISE: 888 973 Both_Sides_Cut
# a typical example is the death of Korean gamer, who had a non-stop playing for 3 days
#
# -----------------
#
# 168
# [((906, 966), (888, 973, 'Premise', 'Both_Sides_Cut'))]
#
# UNIT: is the death of Korean gamer, who had a non-stop playing for
#
# ADU #1 PREMISE: 888 973 Both_Sides_Cut
# a typical example is the death of Korean gamer, who had a non-stop playing for 3 days
#
# -----------------
#
# 169
# [((909, 968), (888, 973, 'Premise', 'Both_Sides_Cut'))]
#
# UNIT: the death of Korean gamer, who had a non-stop playing for 3
#
# ADU #1 PREMISE: 888 973 Both_Sides_Cut
# a typical example is the death of Korean gamer, who had a non-stop playing for 3 days
#
# -----------------
#
# 170
# [((913, 973), (888, 973, 'Premise', 'Start_Cut'))]
#
# UNIT: death of Korean gamer, who had a non-stop playing for 3 days
#
# ADU #1 PREMISE: 888 973 Start_Cut
# a typical example is the death of Korean gamer, who had a non-stop playing for 3 days
#
# -----------------
#
# 171
# [((919, 974), (888, 973, 'Premise', 'Start_Cut'))]
#
# UNIT: of Korean gamer, who had a non-stop playing for 3 days.
#
# ADU #1 PREMISE: 888 973 Start_Cut
# a typical example is the death of Korean gamer, who had a non-stop playing for 3 days
#
# -----------------
#
# 172
# [((922, 975), (888, 973, 'Premise', 'Start_Cut'))]
#
# UNIT: Korean gamer, who had a non-stop playing for 3 days.
#
#
# ADU #1 PREMISE: 888 973 Start_Cut
# a typical example is the death of Korean gamer, who had a non-stop playing for 3 days
#
# -----------------
#
# 173
# ...
#
# ADU #2 PREMISE: 1308 1390 End_Cut
# when they can not live without internet, they will have no time for their studying
#
# -----------------
#
# 249
# [((1290, 1366), (1262, 1299, 'Premise', 'Start_Cut')), ((1290, 1366), (1308, 1390, 'Premise', 'End_Cut'))]
#
# UNIT: in school because when they can not live without internet, they will have no
#
# ADU #1 PREMISE: 1262 1299 Start_Cut
# they will have a bad result in school
#
# ADU #2 PREMISE: 1308 1390 End_Cut
# when they can not live without internet, they will have no time for their studying
#
# -----------------
#
# 250
# [((1293, 1371), (1262, 1299, 'Premise', 'Start_Cut')), ((1293, 1371), (1308, 1390, 'Premise', 'End_Cut'))]
#
# UNIT: school because when they can not live without internet, they will have no time
#
# ADU #1 PREMISE: 1262 1299 Start_Cut
# they will have a bad result in school
#
# ADU #2 PREMISE: 1308 1390 End_Cut
# when they can not live without internet, they will have no time for their studying
#
# -----------------
#
# 251
# [((1300, 1375), (1308, 1390, 'Premise', 'End_Cut'))]
#
# UNIT: because when they can not live without internet, they will have no time for
#
# ADU #1 PREMISE: 1308 1390 End_Cut
# when they can not live without internet, they will have no time for their studying
#
# -----------------
#
# 252
# [((1308, 1381), (1308, 1390, 'Premise', 'End_Cut'))]
#
# UNIT: when they can not live without internet, they will have no time for their
#
# ADU #1 PREMISE: 1308 1390 End_Cut
# when they can not live without internet, they will have no time for their studying
#
# -----------------
#
# 253
# [((1313, 1390), (1308, 1390, 'Premise', 'Start_Cut'))]
#
# UNIT: they can not live without internet, they will have no time for their studying
#
# ADU #1 PREMISE: 1308 1390 Start_Cut
# when they can not live without internet, they will have no time for their studying
#
# -----------------
#
# 254
# [((1318, 1391), (1308, 1390, 'Premise', 'Start_Cut'))]
#
# UNIT: can not live without internet, they will have no time for their studying.
#
# ADU #1 PREMISE: 1308 1390 Start_Cut
# when they can not live without internet, they will have no time for their studying
#
# -----------------
#
# 255
# [((1322, 1392), (1308, 1390, 'Premise', 'Start_Cut'))]
#
# UNIT: not live without internet, they will have no time for their studying.
#
#
# ADU #1 PREMISE: 1308 1390 Start_Cut
# when they can not live without internet, they will have no time for their studying
#
# -----------------
#
# 256
# [((1326, 1394), (1308, 1390, 'Premise', 'Start_Cut'))]
#
# UNIT: live without internet, they will have no time for their studying.
# In
#
# ADU #1 PREMISE: 1308 1390 Start_Cut
# when they can not live without internet, they will have no time for their studying
#
# -----------------
#
# 257
# [((1331, 1405), (1308, 1390, 'Premise', 'Start_Cut'))]
#
# UNIT: without internet, they will have no time for their studying.
# In conclusion
#
# ADU #1 PREMISE: 1308 1390 Start_Cut
# when they can not live without internet, they will have no time for their studying
#
# -----------------
#
# 258
# [((1339, 1406), (1308, 1390, 'Premise', 'Start_Cut'))]
#
# UNIT: internet, they will have no time for their studying.
# In conclusion,
#
# ADU #1 PREMISE: 1308 1390 Start_Cut
# when they can not live without internet, they will have no time for their studying
#
# -----------------
#
# 259
# [((1347, 1415), (1308, 1390, 'Premise', 'Start_Cut'))]
#
# UNIT: , they will have no time for their studying.
# In conclusion, although
#
# ADU #1 PREMISE: 1308 1390 Start_Cut
# when they can not live without internet, they will have no time for their studying
#
# -----------------
#
# 260
# [((1349, 1418), (1416, 1478, 'Claim', 'End_Cut')), ((1349, 1418), (1308, 1390, 'Premise', 'Start_Cut'))]
#
# UNIT: they will have no time for their studying.
# In conclusion, although it
#
# ADU #1 CLAIM: 1416 1478 End_Cut
# it is undeniable that computer is a crucial part of human life
#
# ADU #2 PREMISE: 1308 1390 Start_Cut
# when they can not live without internet, they will have no time for their studying
#
# -----------------
#
# 261
# [((1354, 1421), (1416, 1478, 'Claim', 'End_Cut')), ((1354, 1421), (1308, 1390, 'Premise', 'Start_Cut'))]
#
# UNIT: will have no time for their studying.
# In conclusion, although it is
#
# ADU #1 CLAIM: 1416 1478 End_Cut
# it is undeniable that computer is a crucial part of human life
#
# ADU #2 PREMISE: 1308 1390 Start_Cut
# when they can not live without internet, they will have no time for their studying
#
# -----------------
#
# 262
# [((1359, 1432), (1416, 1478, 'Claim', 'End_Cut')), ((1359, 1432), (1308, 1390, 'Premise', 'Start_Cut'))]
#
# UNIT: have no time for their studying.
# In conclusion, although it is undeniable
#
# ADU #1 CLAIM: 1416 1478 End_Cut
# it is undeniable that computer is a crucial part of human life
#
# ADU #2 PREMISE: 1308 1390 Start_Cut
# when they can not live without internet, they will have no time for their studying
#
# -----------------
#
# 263
# [((1364, 1437), (1416, 1478, 'Claim', 'End_Cut')), ((1364, 1437), (1308, 1390, 'Premise', 'Start_Cut'))]
#
# UNIT: no time for their studying.
# In conclusion, although it is undeniable that
#
# ADU #1 CLAIM: 1416 1478 End_Cut
# it is undeniable that computer is a crucial part of human life
#
# ADU #2 PREMISE: 1308 1390 Start_Cut
# when they can not live without internet, they will have no time for their studying
#
# -----------------
#
# 264
# [((1367, 1446), (1416, 1478, 'Claim', 'End_Cut')), ((1367, 1446), (1308, 1390, 'Premise', 'Start_Cut'))]
#
# UNIT: time for their studying.
# In conclusion, although it is undeniable that computer
#
# ADU #1 CLAIM: 1416 1478 End_Cut
# it is undeniable that computer is a crucial part of human life
#
# ADU #2 PREMISE: 1308 1390 Start_Cut
# when they can not live without internet, they will have no time for their studying
#
# -----------------
#
# 265
# [((1372, 1449), (1416, 1478, 'Claim', 'End_Cut')), ((1372, 1449), (1308, 1390, 'Premise', 'Start_Cut'))]
#
# UNIT: for their studying.
# In conclusion, although it is undeniable that computer is
#
# ADU #1 CLAIM: 1416 1478 End_Cut
# it is undeniable that computer is a crucial part of human life
#
# ADU #2 PREMISE: 1308 1390 Start_Cut
# when they can not live without internet, they will have no time for their studying
#
# -----------------
#
# 266
# [((1376, 1451), (1416, 1478, 'Claim', 'End_Cut')), ((1376, 1451), (1308, 1390, 'Premise', 'Start_Cut'))]
#
# UNIT: their studying.
# In conclusion, although it is undeniable that computer is a
#
# ADU #1 CLAIM: 1416 1478 End_Cut
# it is undeniable that computer is a crucial part of human life
#
# ADU #2 PREMISE: 1308 1390 Start_Cut
# when they can not live without internet, they will have no time for their studying
#
# -----------------
#
# 267
# [((1382, 1459), (1416, 1478, 'Claim', 'End_Cut')), ((1382, 1459), (1308, 1390, 'Premise', 'Start_Cut'))]
#
# UNIT: studying.
# In conclusion, although it is undeniable that computer is a crucial
#
# ADU #1 CLAIM: 1416 1478 End_Cut
# it is undeniable that computer is a crucial part of human life
#
# ADU #2 PREMISE: 1308 1390 Start_Cut
# when they can not live without internet, they will have no time for their studying
#
# -----------------
#
# 268
# [((1390, 1464), (1416, 1478, 'Claim', 'End_Cut'))]
#
# UNIT: .
# In conclusion, although it is undeniable that computer is a crucial part
#
# ADU #1 CLAIM: 1416 1478 End_Cut
# it is undeniable that computer is a crucial part of human life
#
# -----------------
#
# 269
# [((1391, 1467), (1416, 1478, 'Claim', 'End_Cut'))]
#
# UNIT:
# In conclusion, although it is undeniable that computer is a crucial part of
#
# ADU #1 CLAIM: 1416 1478 End_Cut
# it is undeniable that computer is a crucial part of human life
#
# -----------------
#
# 270
# [((1392, 1473), (1416, 1478, 'Claim', 'End_Cut'))]
#
# UNIT: In conclusion, although it is undeniable that computer is a crucial part of human
#
# ADU #1 CLAIM: 1416 1478 End_Cut
# it is undeniable that computer is a crucial part of human life
#
# -----------------
#
# 271
# [((1395, 1478), (1416, 1478, 'Claim', 'Full'))]
#
# UNIT: conclusion, although it is undeniable that computer is a crucial part of human life
#
# ADU #1 CLAIM: 1416 1478 Full
# it is undeniable that computer is a crucial part of human life
#
# -----------------
#
# 272
# [((1405, 1479), (1416, 1478, 'Claim', 'Full'))]
#
# UNIT: , although it is undeniable that computer is a crucial part of human life,
#
# ADU #1 CLAIM: 1416 1478 Full
# it is undeniable that computer is a crucial part of human life
#
# -----------------
#
# 273
# [((1407, 1482), (1480, 1530, 'Claim', 'End_Cut')), ((1407, 1482), (1416, 1478, 'Claim', 'Full'))]
#
# UNIT: although it is undeniable that computer is a crucial part of human life, it
#
# ADU #1 CLAIM: 1480 1530 End_Cut
# it still has its bad side, especially for children
#
# ADU #2 CLAIM: 1416 1478 Full
# it is undeniable that computer is a crucial part of human life
#
# -----------------
#
# 274
# [((1416, 1488), (1480, 1530, 'Claim', 'End_Cut')), ((1416, 1488), (1416, 1478, 'Claim', 'Full'))]
#
# UNIT: it is undeniable that computer is a crucial part of human life, it still
#
# ADU #1 CLAIM: 1480 1530 End_Cut
# it still has its bad side, especially for children
#
# ADU #2 CLAIM: 1416 1478 Full
# it is undeniable that computer is a crucial part of human life
#
# -----------------
#
# 275
# [((1419, 1492), (1480, 1530, 'Claim', 'End_Cut')), ((1419, 1492), (1416, 1478, 'Claim', 'Start_Cut'))]
#
# UNIT: is undeniable that computer is a crucial part of human life, it still has
#
# ADU #1 CLAIM: 1480 1530 End_Cut
# it still has its bad side, especially for children
#
# ADU #2 CLAIM: 1416 1478 Start_Cut
# it is undeniable that computer is a crucial part of human life
#
# -----------------
#
# 276
# [((1422, 1496), (1480, 1530, 'Claim', 'End_Cut')), ((1422, 1496), (1416, 1478, 'Claim', 'Start_Cut'))]
#
# UNIT: undeniable that computer is a crucial part of human life, it still has its
#
# ADU #1 CLAIM: 1480 1530 End_Cut
# it still has its bad side, especially for children
#
# ADU #2 CLAIM: 1416 1478 Start_Cut
# it is undeniable that computer is a crucial part of human life
#
# -----------------
#
# 277
# [((1433, 1500), (1480, 1530, 'Claim', 'End_Cut')), ((1433, 1500), (1416, 1478, 'Claim', 'Start_Cut'))]
#
# UNIT: that computer is a crucial part of human life, it still has its bad
#
# ADU #1 CLAIM: 1480 1530 End_Cut
# it still has its bad side, especially for children
#
# ADU #2 CLAIM: 1416 1478 Start_Cut
# it is undeniable that computer is a crucial part of human life
#
# -----------------
#
# 278
# [((1438, 1505), (1480, 1530, 'Claim', 'End_Cut')), ((1438, 1505), (1416, 1478, 'Claim', 'Start_Cut'))]
#
# UNIT: computer is a crucial part of human life, it still has its bad side
#
# ADU #1 CLAIM: 1480 1530 End_Cut
# it still has its bad side, especially for children
#
# ADU #2 CLAIM: 1416 1478 Start_Cut
# it is undeniable that computer is a crucial part of human life
#
# -----------------
#
# 279
# [((1447, 1506), (1480, 1530, 'Claim', 'End_Cut')), ((1447, 1506), (1416, 1478, 'Claim', 'Start_Cut'))]
#
# UNIT: is a crucial part of human life, it still has its bad side,
#
# ADU #1 CLAIM: 1480 1530 End_Cut
# it still has its bad side, especially for children
#
# ADU #2 CLAIM: 1416 1478 Start_Cut
# it is undeniable that computer is a crucial part of human life
#
# -----------------
# 280
# [((1450, 1517), (1480, 1530, 'Claim', 'End_Cut')), ((1450, 1517), (1416, 1478, 'Claim', 'Start_Cut'))]
#
# UNIT: a crucial part of human life, it still has its bad side, especially
#
# ADU #1 CLAIM: 1480 1530 End_Cut
# it still has its bad side, especially for children
#
# ADU #2 CLAIM: 1416 1478 Start_Cut
# it is undeniable that computer is a crucial part of human life
#
# -----------------
#
# 281
# [((1452, 1521), (1480, 1530, 'Claim', 'End_Cut')), ((1452, 1521), (1416, 1478, 'Claim', 'Start_Cut'))]
#
# UNIT: crucial part of human life, it still has its bad side, especially for
#
# ADU #1 CLAIM: 1480 1530 End_Cut
# it still has its bad side, especially for children
#
# ADU #2 CLAIM: 1416 1478 Start_Cut
# it is undeniable that computer is a crucial part of human life
#
# -----------------
#
# 282
# [((1460, 1530), (1480, 1530, 'Claim', 'Full')), ((1460, 1530), (1416, 1478, 'Claim', 'Start_Cut'))]
#
# UNIT: part of human life, it still has its bad side, especially for children
#
# ADU #1 CLAIM: 1480 1530 Full
# it still has its bad side, especially for children
#
# ADU #2 CLAIM: 1416 1478 Start_Cut
# it is undeniable that computer is a crucial part of human life
#
# -----------------
#
# 283
# [((1465, 1531), (1480, 1530, 'Claim', 'Full')), ((1465, 1531), (1416, 1478, 'Claim', 'Start_Cut'))]
#
# UNIT: of human life, it still has its bad side, especially for children.
#
# ADU #1 CLAIM: 1480 1530 Full
# it still has its bad side, especially for children
#
# ADU #2 CLAIM: 1416 1478 Start_Cut
# it is undeniable that computer is a crucial part of human life
#
# -----------------
#
# 284
# [((1468, 1538), (1480, 1530, 'Claim', 'Full')), ((1468, 1538), (1416, 1478, 'Claim', 'Start_Cut'))]
#
# UNIT: human life, it still has its bad side, especially for children. People
#
# ADU #1 CLAIM: 1480 1530 Full
# it still has its bad side, especially for children
#
# ADU #2 CLAIM: 1416 1478 Start_Cut
# it is undeniable that computer is a crucial part of human life
#
# -----------------
#
# 285
# [((1474, 1545), (1480, 1530, 'Claim', 'Full')), ((1474, 1545), (1416, 1478, 'Claim', 'Start_Cut'))]
#
# UNIT: life, it still has its bad side, especially for children. People should
#
# ADU #1 CLAIM: 1480 1530 Full
# it still has its bad side, especially for children
#
# ADU #2 CLAIM: 1416 1478 Start_Cut
# it is undeniable that computer is a crucial part of human life
#
# -----------------
#
# 286
# [((1478, 1551), (1480, 1530, 'Claim', 'Full'))]
#
# UNIT: , it still has its bad side, especially for children. People should learn
#
# ADU #1 CLAIM: 1480 1530 Full
# it still has its bad side, especially for children
#
# -----------------
#
# 287
# [((1480, 1555), (1480, 1530, 'Claim', 'Full'))]
#
# UNIT: it still has its bad side, especially for children. People should learn how
#
# ADU #1 CLAIM: 1480 1530 Full
# it still has its bad side, especially for children
#
# -----------------
#
# 288
# [((1483, 1558), (1480, 1530, 'Claim', 'Start_Cut'))]
#
# UNIT: still has its bad side, especially for children. People should learn how to
#
# ADU #1 CLAIM: 1480 1530 Start_Cut
# it still has its bad side, especially for children
#
# -----------------
#
# 289
# [((1489, 1562), (1480, 1530, 'Claim', 'Start_Cut'))]
#
# UNIT: has its bad side, especially for children. People should learn how to use
#
# ADU #1 CLAIM: 1480 1530 Start_Cut
# it still has its bad side, especially for children
#
# -----------------
#
# 290
# [((1493, 1565), (1480, 1530, 'Claim', 'Start_Cut'))]
#
# UNIT: its bad side, especially for children. People should learn how to use it
#
# ADU #1 CLAIM: 1480 1530 Start_Cut
# it still has its bad side, especially for children
#
# -----------------
#
# 291
# [((1497, 1574), (1480, 1530, 'Claim', 'Start_Cut'))]
#
# UNIT: bad side, especially for children. People should learn how to use it properly
#
# ADU #1 CLAIM: 1480 1530 Start_Cut
# it still has its bad side, especially for children
#
# -----------------
#
# 292
# [((1501, 1577), (1480, 1530, 'Claim', 'Start_Cut'))]
#
# UNIT: side, especially for children. People should learn how to use it properly to
#
# ADU #1 CLAIM: 1480 1530 Start_Cut
# it still has its bad side, especially for children
#
# -----------------
#
# 293
# [((1505, 1582), (1480, 1530, 'Claim', 'Start_Cut'))]
#
# UNIT: , especially for children. People should learn how to use it properly to make
#
# ADU #1 CLAIM: 1480 1530 Start_Cut
# it still has its bad side, especially for children
#
# -----------------
#
# 294
# [((1507, 1585), (1480, 1530, 'Claim', 'Start_Cut'))]
#
# UNIT: especially for children. People should learn how to use it properly to make it
#
# ADU #1 CLAIM: 1480 1530 Start_Cut
# it still has its bad side, especially for children
#
# -----------------
#
# 295
# [((1518, 1588), (1480, 1530, 'Claim', 'Start_Cut'))]
#
# UNIT: for children. People should learn how to use it properly to make it an
#
# ADU #1 CLAIM: 1480 1530 Start_Cut
# it still has its bad side, especially for children
#
# -----------------
#
# 296
# [((1522, 1598), (1480, 1530, 'Claim', 'Start_Cut'))]
#
# UNIT: children. People should learn how to use it properly to make it an effective
#
# ADU #1 CLAIM: 1480 1530 Start_Cut
# it still has its bad side, especially for children
#
# -----------------

# %%
units[66]
# Out:
# children's eyes. When they concentrate on computer for too long, their eyes

# %%
units[61]._.get_label_and_error(error_function="percentage_correctness")
# Out:
# [('Claim', 0.5333333333333333), ('Premise', 0.4)]

# %%
units[61]._.get_label_and_error(error_function="extended_accuracy")[0][1]
# Out:
# (-2, 0.21022410381342865, 7)

# %% [markdown]
# # Classification

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report

# %%
logreg = LogisticRegression(solver='newton-cg')
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(solver='newton-cg')

# %%
preds_lr = logreg.predict(X_test)
print(classification_report(y_test, preds_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.50      0.44         8
#            1       0.93      0.90      0.91        58
#
#     accuracy                           0.85        66
#    macro avg       0.66      0.70      0.68        66
# weighted avg       0.86      0.85      0.86        66

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
preds = rf.predict(X_test)

confusion_matrix(y_test, preds)
# Out:
# array([[ 168,   94],
#        [  22, 1113]])

# %%
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.64      0.74       262
#            1       0.92      0.98      0.95      1135
#
#     accuracy                           0.92      1397
#    macro avg       0.90      0.81      0.85      1397
# weighted avg       0.92      0.92      0.91      1397

# %% [markdown]
# ## CrossValidation

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import SGDClassifier
from sklearn.base import clone

# %%
""" Stochastic Gradient Descent (SGD) classifier, 
This classifier has the advantage of being capable of handling very large datasets efficiently"""
sgd_clf = SGDClassifier(random_state=42)
sgd_clf.fit(X_train, y_train)
# Out:
# SGDClassifier(random_state=42)

# %%
skfolds = StratifiedKFold(n_splits=5, random_state=42)

best_model = None 
precision = 0
for train_index, test_index in skfolds.split(X_train, y_train):
    clone_clf = clone(sgd_clf)
    X_train_folds = X_train[train_index]
    y_train_folds = y_train[train_index]
    X_test_fold = X_train[test_index]
    y_test_fold = y_train[test_index]
    
    clone_clf.fit(X_train_folds, y_train_folds)
    y_pred = clone_clf.predict(X_test_fold)
    n_correct = sum(y_pred == y_test_fold)
    if precision < n_correct / len(y_pred):
        best_model = clone_clf
        precision = n_correct / len(y_pred)
    print(n_correct / len(y_pred))
    print(confusion_matrix(y_test_fold, y_pred))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# 0.7224231464737794
# [[181  53]
#  [254 618]]
# 0.8707052441229657
# [[145  89]
#  [ 54 818]]
# 0.8471971066907775
# [[110 124]
#  [ 45 827]]
# 0.8426763110307414
# [[ 69 164]
#  [ 10 863]]
# 0.8090497737556561
# [[183  50]
#  [161 711]]

# %%
preds = best_model.predict(X_test)

confusion_matrix(y_test, preds)
# Out:
# array([[ 173,   89],
#        [  81, 1054]])

# %%
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.66      0.67       262
#            1       0.92      0.93      0.93      1135
#
#     accuracy                           0.88      1397
#    macro avg       0.80      0.79      0.80      1397
# weighted avg       0.88      0.88      0.88      1397

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC

# %%
svm_clf = LinearSVC(random_state=0, tol=1e-5, verbose=1, max_iter=50000)

# %%
svm_clf.fit(X_train, y_train)
# Out:
# [LibLinear]
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# LinearSVC(max_iter=50000, random_state=0, tol=1e-05, verbose=1)

# %%
preds = svm_clf.predict(X_test)

confusion_matrix(y_test, preds)
# Out:
# array([[ 127,  135],
#        [  35, 1100]])

# %%
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.48      0.60       262
#            1       0.89      0.97      0.93      1135
#
#     accuracy                           0.88      1397
#    macro avg       0.84      0.73      0.76      1397
# weighted avg       0.87      0.88      0.87      1397

# %%
from sklearn import svm
svm_clf = svm.SVC(kernel='linear')

# %%
svm_clf.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
preds = svm_clf.predict(X_test)

confusion_matrix(y_test, preds)
# Out:
# array([[ 132,  130],
#        [  32, 1103]])

# %%
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.50      0.62       262
#            1       0.89      0.97      0.93      1135
#
#     accuracy                           0.88      1397
#    macro avg       0.85      0.74      0.78      1397
# weighted avg       0.88      0.88      0.87      1397

# %% [markdown]
# ### Hard Voting

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
log_clf = LogisticRegression(solver='newton-cg')
rnd_clf = RandomForestClassifier()
smv_clf = SVC()

# %%
voting_clf = VotingClassifier(
    estimators=[('lr', log_clf), ('rf', rnd_clf), ('svc', smv_clf)],
    voting='hard')
voting_clf.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('lr', LogisticRegression(solver='newton-cg')),
#                              ('rf', RandomForestClassifier()), ('svc', SVC())])

# %%
for clf in (log_clf, rnd_clf, svm_clf, voting_clf):
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print(clf.__class__.__name__, accuracy_score(y_test, y_pred))
# Out:
# LogisticRegression 0.8869005010737294
# RandomForestClassifier 0.9112383679312813
# SVC 0.8840372226198998
# VotingClassifier 0.9226914817465999

# %%
preds = voting_clf.predict(X_test)

confusion_matrix(y_test, preds)
# Out:
# array([[ 176,   86],
#        [  22, 1113]])

# %%
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.67      0.77       262
#            1       0.93      0.98      0.95      1135
#
#     accuracy                           0.92      1397
#    macro avg       0.91      0.83      0.86      1397
# weighted avg       0.92      0.92      0.92      1397

# %% [markdown]
# ## Bagging and Pasting

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
bag_clf = BaggingClassifier(
        DecisionTreeClassifier(), n_estimators=500,
        max_samples=100, bootstrap=True, n_jobs=-1)

# %%
bag_clf.fit(X_train, y_train)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(), max_samples=100,
#                   n_estimators=500, n_jobs=-1)

# %%
preds = bag_clf.predict(X_test)

confusion_matrix(y_test, preds)
# Out:
# array([[ 179,   83],
#        [  61, 1074]])

# %%
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.68      0.71       262
#            1       0.93      0.95      0.94      1135
#
#     accuracy                           0.90      1397
#    macro avg       0.84      0.81      0.83      1397
# weighted avg       0.89      0.90      0.90      1397
