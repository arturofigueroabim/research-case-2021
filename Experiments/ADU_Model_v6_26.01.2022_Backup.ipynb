# %%
import numpy as np
import pandas as pd
import spacy
from spacy.tokens import Doc, Span, Token
nlp = spacy.load("en_core_web_md")
import re

from itertools import chain

# %%
#from spacy import displacy
#import deplacy

# %%
doc_features = ['num_tokens', 'para_starts']
span_features = ['word_emb', 'num_tokens', 'num_verbs', 'num_pos_pronouns', 'num_conj_adv', 'num_punct', 'is_para_start',
                 'index_in_doc']

# getters that are not used as features
span_utilities = ['prev_unit', 'label', 'idx_start', 'idx_end']
# methods
span_methods = ['get_nth_unit', 'get_prev_unit_attr', 'get_label_and_error']
token_features =['word_emb']



extensions_dict = dict(doc_features=doc_features, span_features=span_features+span_utilities,
                       token_features=token_features, span_methods=span_methods)





def create_extensions(extensions_dict=None, force=True):
    
    # Features that take 'unit' as input refer to the segmentation, they do not work with just any span.
    
    # Property attributes
    
    # Store starting and ending indices of spans in the whole doc
    # 1 list per each document: [(s1_start, s1_end), (s2_start, s2_end),.., (sn_start, sn_end)]
    Doc.set_extension("units_index_list", default=[],force=True)
    
    # Store essay_id within doc
    Doc.set_extension("essay_id", default=None, force=True)

    
    # Feature Getters
    def get_label_and_error(unit, error_function='percentage_correctness'):
        """
        Inputs: unit

        Outputs: label for the unit and segmentation error

        """

        def overlap_case(unit_start, unit_end, adu_start, adu_end):
            if adu_start >= unit_start and adu_end <= unit_end:
                # Case 1, ADU is fully contained in UNIT
                return 1

            elif adu_start <= unit_start and adu_end <=unit_end and adu_end>=unit_start:

                # Case 2, ADU starts before UNIT, start(Left) of ADU is cut
                return 2

            elif adu_start >= unit_start and adu_end >= unit_end and adu_start<unit_end:

                # Case 3, ADU starts after UNIT, end(Right) of ADU is cut
                return 3

            elif adu_start < unit_start and adu_end > unit_end:

                # Case 4, ADU starts before UNIT and ends after UNIT, both sides of ADU are cut
                return 4

            else: 
                # ADU does not overlap with UNIT
                return False


        def percentage_correctness(unit, adu_start, adu_end, overlap_case):

            if overlap_case==2:
                adu_start = unit._.idx_start
            if overlap_case==3:
                adu_end = unit._.idx_end

            adu = unit.doc.char_span(adu_start, adu_end, alignment_mode='expand')
            

            unit_ntokens = len(unit)
            adu_ntokens = len(adu)
            pct_correct = adu_ntokens/unit_ntokens
            return pct_correct

        def extended_accuracy(unit, adu_start, adu_end, overlap_case):
            # Compares number of tokens to get the the correct ADU in proportional with UNIT length

            adu = unit.doc.char_span(adu_start, adu_end, alignment_mode='expand')

            unit_ntokens = len(unit)
            adu_ntokens = len(adu)
            diff_ntokens = np.abs(unit_ntokens - adu_ntokens)

            return 1/((diff_ntokens+1)**(np.log2(diff_ntokens+1)/np.log2(unit_ntokens+1)))


        if error_function.lower() == 'percentage_correctness':
            err_func = percentage_correctness
        elif error_function.lower() == 'extended_accuracy':
            err_func = extended_accuracy

        unit_start = unit._.idx_start
        unit_end = unit._.idx_end

        essay_id = u.doc._.essay_id

        # DataFrame containing ADUs indices & labels, filtered for current essay_id
        adus_doc = adus[adus['essay_id'] == essay_id]



        label_and_error = [(row['ADU_type'], err_func(unit, row['start_ind'],row['end_ind'], 
                          overlap_case(unit_start, unit_end,row['start_ind'], row['end_ind'])),
                          #(row['start_ind'], row['end_ind'])
                           ) 
                         for row_ind, row in adus_doc.iterrows() 
                         if unit_start <= row['end_ind'] and unit_end >= row['start_ind']]

    #     # Contains information of the ADUs that overlap with the UNIT
    #     # Structure: (adu_start, adu_end, overlap_case, ADU_type)
    #     overlap_adus = [(row['start_ind'],
    #                      row['end_ind'], 
    #                      overlap_case(unit_start, unit_end,row['start_ind'], row['end_ind']), 
    #                      row['ADU_type']) 
    #                      for row_ind, row in adus_doc.iterrows()
    #           if unit_start <= row['end_ind'] and unit_end >= row['start_ind']]

        return label_and_error

    
    def get_label(span):
        
        # Gets ADU vs non-ADU LABEL for the span (intended only for sentences)

        # Works if the span is larger or equal to the adu

        # TODO:
        # DOES NOT WORK IF SPAN IS SMALLER THAN ADU, OR IF ADU IS SPLIT BETWEEN TWO SPANS (NEEDS MORE WORK!!!)
        # CLAIM VS PREMISE
        essay_id = span.doc._.essay_id

        span_start = span[0].idx
        #  + len(span[-1]) to get to the end of the last word
        span_end = span[-1].idx  + len(span[-1])
        start_inds = adus[adus['essay_id'] == essay_id ]['start_ind'].values
        end_inds = adus[adus['essay_id'] == essay_id ]['end_ind'].values

        # Checks if starting index of span is smaller than ADU and the ending index of the span is larger than the ADU
        return ((start_inds >= span_start) & (end_inds <= span_end)).any()
    
    def get_idx_start(unit):
        return unit[0].idx
    
    def get_idx_end(unit):
        return unit[-1].idx  + len(unit[-1])
    
    def get_label_pct(span):
        
        
        pass
    
    def get_para_starts(doc):
        # Units starting with \n or preceding \n are considered as paragraph starts
        # if start is 0, start -1 goes back to the last token of the doc

        # TODO
        # para_ends can be obtained by shifing this list to the right by one position
        return [int(doc[start].text =='\n' or doc[start-1].text=='\n') for start, end in doc._.units_index_list]
    
    def get_is_para_start(unit):
        
        para_starts = unit.doc._.para_starts
        unit_ind = unit._.index_in_doc
        
        return para_starts[unit_ind]
        
    
    def get_word_emb(obj):
        return obj.vector
    
    def get_num_tokens(obj):
        return len(obj)
    
    def get_num_verbs(span):
        return sum([1 for token in span if token.pos_ == "VERB"])

    def get_num_pos_pronouns(span):
        return sum([1 for token in span if token.tag_ == "PRP$"])

    def get_num_pron(span):
        return sum([1 for token in span if token.pos_ == "PRON"])
    
    def get_num_conj_adv(span):
        conj_advs = ['moreover', 'incidentally', 'next', 'yet', 'finally', 'then', 'for example', 'thus', 'accordingly', 'namely', 'meanwhile', 'that is', 'also', 'undoubtedly', 'all in all', 'lately', 'hence', 'still', 'therefore', 'in addition', 'indeed', 'again', 'so', 'nevertheless', 'besides', 'instead', 'for instance', 'certainly', 'however', 'anyway', 'further', 'furthermore', 'similarly', 'now', 'in conclusion', 'nonetheless', 'thereafter', 'likewise', 'otherwise', 'consequently']
        return sum([len(re.findall(adv, span.text.lower())) for adv in conj_advs])
    
    def get_num_punct(span):
        return sum([1 for token in span if token.tag_ == "."])
    

    def get_index_in_doc(span):
        """Gets index of the segmented unit in the doc"""
        span_start = span.start

        # span end not used yet
        span_end = span.end

        # finds where span_start is in units_index_list [(s1_start, s1_end), (s2_start, s2_end),.., (sn_start, sn_end)]
        # returns the index of the corresponding span
        return np.where([span.start in range(start, end) for start, end in span.doc._.units_index_list])[0][-1]


    def get_prev_unit(span):

        return span._.get_nth_unit(span._.index_in_doc-1)
    
        
    def get_nth_unit(span, n):

        # Tuple containing the start and end index of the nth span
        span_index = span.doc._.units_index_list[n]

        # Return nth span
        return span.doc[span_index[0]: span_index[1]]



    def get_prev_unit_attr(span, attribute):

        return span._.prev_unit._.get(attribute)
    
    

    # Iterate list of features and Set Extensions (Just to not manually set extensions one by one)
    
    for feature in extensions_dict['doc_features']:
        Doc.set_extension(feature, force=force, getter=locals()[f"get_{feature}"])
        
    for feature in extensions_dict['span_features']:
        Span.set_extension(feature, force=force, getter=locals()[f"get_{feature}"])
        
    for feature in extensions_dict['token_features']:
        Token.set_extension(feature, force=force, getter=locals()[f"get_{feature}"])
        
    for method in extensions_dict['span_methods']:
        Span.set_extension(method, force=force, method=locals()[method])


def segmentation(doc=None ,mode = 'sentence', n_grams=15):
    if mode=='paragraph':
        pass
    if mode=='sentence':
        # segment by sentences
        units = [sent for sent in doc.sents  if not (sent.text.isspace() or sent.text =='')] 
        
        # keep track of (start, end) of units in doc object
        doc._.units_index_list = [(unit.start, unit.end) for unit in units]
        return units
    
    if mode =='n_grams':
        # Code to segment with 15 grams here (average)  
        units = [doc[i:i+n_grams] for i in range(len(doc))]

        doc._.units_index_list = [(unit.start, unit.end) for unit in units]

        return units
    
    if mode=='clause':
        # Code to segment by clause
        pass
    if mode=='token':
        return [token for token in doc if not (token.text.isspace() or token.text =='')]

def unit2fv(unit, feature_list):
    
    fv = np.array([unit._.get(feature) for feature in feature_list], dtype='object')
    
    _fv = np.array([np.reshape(feature, -1) for feature in fv], dtype='object')
    
    return np.concatenate(_fv)

# Run
create_extensions(extensions_dict)

# %%
# Optional, not used yet. Trying to solve problem that title gets included with the first sentence
def add_full_stops(text):
    """adds full stops to texts that end with \n missing full stops"""
    return re.sub("\n+(?!\.)",'.\n', text)
# Not used
def text2doc(text):
    # need to use nlp.pipe here instead
    return nlp(text)

# %%
# Pipelinev1

def text2fv(df):
    data = [(row['text'], dict(id=row['essay_id'])) for ind, row in df.iterrows()]
    docs = []
    data
    for doc, context in nlp.pipe(data, as_tuples=True):
        doc._.essay_id = context['id']
        docs.append(doc)
        
    segmented_docs = [segmentation(doc, mode='sentence') for doc in docs]
    
    # Flatten lists (Dissolve docs boundaries and store all units together in one huge list)
    units = list(chain.from_iterable(segmented_docs))
    
    X_features = span_features
    

    X = np.array([unit2fv(unit, X_features) for unit in units])
    y = np.array([int(unit._.label) for unit in units])
    
    return X,y

# %%
def print_adus(units):
    for i, u in enumerate(units):
            unit_start = u._.idx_start
            unit_end = u._.idx_end
            
            essay_id = u.doc._.essay_id
            
            
            doc_adus = adus[adus['essay_id'] == essay_id]
             
            lis = [((unit_start, unit_end),(row['start_ind'], row['end_ind'], row['ADU_type'],is_adu(unit_start, unit_end, row['start_ind'] ,row['end_ind']))) for row_ind,row in doc_adus.iterrows() if is_adu(unit_start, unit_end, row['start_ind'] ,row['end_ind'])]
            
            
            
            if len(lis)>0:
                print(i, lis)
                
print_adus(units)
# Out:
# 45 [((259, 316), (311, 373, 'Claim', 'End_Cut'))]
# 46 [((261, 325), (311, 373, 'Claim', 'End_Cut'))]
# 47 [((264, 336), (311, 373, 'Claim', 'End_Cut'))]
# 48 [((267, 340), (311, 373, 'Claim', 'End_Cut'))]
# 49 [((274, 344), (311, 373, 'Claim', 'End_Cut'))]
# 50 [((276, 354), (311, 373, 'Claim', 'End_Cut'))]
# 51 [((280, 357), (311, 373, 'Claim', 'End_Cut'))]
# 52 [((287, 366), (311, 373, 'Claim', 'End_Cut'))]
# 53 [((295, 368), (311, 373, 'Claim', 'End_Cut'))]
# 54 [((298, 373), (311, 373, 'Claim', 'Full'))]
# 55 [((302, 374), (311, 373, 'Claim', 'Full'))]
# 56 [((303, 379), (311, 373, 'Claim', 'Full')), ((303, 379), (375, 521, 'Premise', 'End_Cut'))]
# 57 [((304, 384), (311, 373, 'Claim', 'Full')), ((304, 384), (375, 521, 'Premise', 'End_Cut'))]
# 58 [((309, 396), (311, 373, 'Claim', 'Full')), ((309, 396), (375, 521, 'Premise', 'End_Cut'))]
# 59 [((311, 399), (311, 373, 'Claim', 'Full')), ((311, 399), (375, 521, 'Premise', 'End_Cut'))]
# 60 [((317, 408), (311, 373, 'Claim', 'Start_Cut')), ((317, 408), (375, 521, 'Premise', 'End_Cut'))]
# 61 [((326, 412), (311, 373, 'Claim', 'Start_Cut')), ((326, 412), (375, 521, 'Premise', 'End_Cut'))]
# 62 [((337, 416), (311, 373, 'Claim', 'Start_Cut')), ((337, 416), (375, 521, 'Premise', 'End_Cut'))]
# 63 [((341, 421), (311, 373, 'Claim', 'Start_Cut')), ((341, 421), (375, 521, 'Premise', 'End_Cut'))]
# 64 [((345, 422), (311, 373, 'Claim', 'Start_Cut')), ((345, 422), (375, 521, 'Premise', 'End_Cut'))]
# 65 [((355, 428), (311, 373, 'Claim', 'Start_Cut')), ((355, 428), (375, 521, 'Premise', 'End_Cut'))]
# 66 [((358, 433), (311, 373, 'Claim', 'Start_Cut')), ((358, 433), (375, 521, 'Premise', 'End_Cut'))]
# 67 [((366, 438), (311, 373, 'Claim', 'Start_Cut')), ((366, 438), (375, 521, 'Premise', 'End_Cut'))]
# 68 [((369, 442), (311, 373, 'Claim', 'Start_Cut')), ((369, 442), (375, 521, 'Premise', 'End_Cut'))]
# 69 [((373, 448), (375, 521, 'Premise', 'End_Cut'))]
# 70 [((375, 449), (375, 521, 'Premise', 'End_Cut'))]
# 71 [((380, 455), (375, 521, 'Premise', 'Both_Sides_Cut'))]
# 72 [((385, 458), (375, 521, 'Premise', 'Both_Sides_Cut'))]
# 73 [((397, 462), (375, 521, 'Premise', 'Both_Sides_Cut'))]
# 74 [((400, 467), (375, 521, 'Premise', 'Both_Sides_Cut'))]
# 75 [((409, 474), (375, 521, 'Premise', 'Both_Sides_Cut'))]
# 76 [((413, 478), (375, 521, 'Premise', 'Both_Sides_Cut'))]
# 77 [((417, 483), (375, 521, 'Premise', 'Both_Sides_Cut'))]
# 78 [((421, 488), (375, 521, 'Premise', 'Both_Sides_Cut'))]
# 79 [((423, 497), (375, 521, 'Premise', 'Both_Sides_Cut'))]
# 80 [((429, 498), (375, 521, 'Premise', 'Both_Sides_Cut'))]
# 81 [((434, 508), (375, 521, 'Premise', 'Both_Sides_Cut'))]
# 82 [((439, 521), (375, 521, 'Premise', 'Start_Cut'))]
# 83 [((443, 522), (375, 521, 'Premise', 'Start_Cut'))]
# 84 [((448, 523), (375, 521, 'Premise', 'Start_Cut'))]
# 85 [((450, 531), (375, 521, 'Premise', 'Start_Cut'))]
# 86 [((456, 532), (375, 521, 'Premise', 'Start_Cut'))]
# 87 [((459, 541), (375, 521, 'Premise', 'Start_Cut')), ((459, 541), (533, 617, 'Premise', 'End_Cut'))]
# 88 [((463, 545), (375, 521, 'Premise', 'Start_Cut')), ((463, 545), (533, 617, 'Premise', 'End_Cut'))]
# 89 [((468, 550), (375, 521, 'Premise', 'Start_Cut')), ((468, 550), (533, 617, 'Premise', 'End_Cut'))]
# 90 [((475, 556), (375, 521, 'Premise', 'Start_Cut')), ((475, 556), (533, 617, 'Premise', 'End_Cut'))]
# 91 [((479, 560), (375, 521, 'Premise', 'Start_Cut')), ((479, 560), (533, 617, 'Premise', 'End_Cut'))]
# 92 [((484, 565), (375, 521, 'Premise', 'Start_Cut')), ((484, 565), (533, 617, 'Premise', 'End_Cut'))]
# 93 [((489, 568), (375, 521, 'Premise', 'Start_Cut')), ((489, 568), (533, 617, 'Premise', 'End_Cut'))]
# 94 [((497, 577), (375, 521, 'Premise', 'Start_Cut')), ((497, 577), (533, 617, 'Premise', 'End_Cut'))]
# 95 [((499, 581), (375, 521, 'Premise', 'Start_Cut')), ((499, 581), (533, 617, 'Premise', 'End_Cut'))]
# 96 [((509, 591), (375, 521, 'Premise', 'Start_Cut')), ((509, 591), (533, 617, 'Premise', 'End_Cut'))]
# 97 [((521, 596), (533, 617, 'Premise', 'End_Cut'))]
# 98 [((522, 610), (533, 617, 'Premise', 'End_Cut'))]
# 99 [((523, 617), (533, 617, 'Premise', 'Full'))]
# 100 [((531, 618), (533, 617, 'Premise', 'Full'))]
# 101 [((533, 623), (533, 617, 'Premise', 'Full')), ((533, 623), (619, 663, 'Premise', 'End_Cut'))]
# 102 [((542, 628), (533, 617, 'Premise', 'Start_Cut')), ((542, 628), (619, 663, 'Premise', 'End_Cut'))]
# 103 [((546, 633), (533, 617, 'Premise', 'Start_Cut')), ((546, 633), (619, 663, 'Premise', 'End_Cut'))]
# 104 [((551, 640), (533, 617, 'Premise', 'Start_Cut')), ((551, 640), (619, 663, 'Premise', 'End_Cut'))]
# 105 [((557, 646), (533, 617, 'Premise', 'Start_Cut')), ((557, 646), (619, 663, 'Premise', 'End_Cut'))]
# 106 [((561, 650), (533, 617, 'Premise', 'Start_Cut')), ((561, 650), (619, 663, 'Premise', 'End_Cut'))]
# 107 [((566, 658), (533, 617, 'Premise', 'Start_Cut')), ((566, 658), (619, 663, 'Premise', 'End_Cut'))]
# 108 [((569, 663), (533, 617, 'Premise', 'Start_Cut')), ((569, 663), (619, 663, 'Premise', 'Full'))]
# 109 [((578, 664), (533, 617, 'Premise', 'Start_Cut')), ((578, 664), (619, 663, 'Premise', 'Full'))]
# 110 [((582, 667), (533, 617, 'Premise', 'Start_Cut')), ((582, 667), (619, 663, 'Premise', 'Full'))]
# 111 [((592, 670), (533, 617, 'Premise', 'Start_Cut')), ((592, 670), (619, 663, 'Premise', 'Full'))]
# 112 [((597, 672), (533, 617, 'Premise', 'Start_Cut')), ((597, 672), (619, 663, 'Premise', 'Full'))]
# 113 [((611, 677), (533, 617, 'Premise', 'Start_Cut')), ((611, 677), (619, 663, 'Premise', 'Full'))]
# 114 [((617, 678), (619, 663, 'Premise', 'Full'))]
# 115 [((619, 683), (619, 663, 'Premise', 'Full'))]
# 116 [((624, 688), (619, 663, 'Premise', 'Start_Cut'))]
# 117 [((629, 693), (619, 663, 'Premise', 'Start_Cut'))]
# 118 [((634, 700), (694, 795, 'Claim', 'End_Cut')), ((634, 700), (619, 663, 'Premise', 'Start_Cut'))]
# 119 [((641, 704), (694, 795, 'Claim', 'End_Cut')), ((641, 704), (619, 663, 'Premise', 'Start_Cut'))]
# 120 [((647, 708), (694, 795, 'Claim', 'End_Cut')), ((647, 708), (619, 663, 'Premise', 'Start_Cut'))]
# 121 [((651, 717), (694, 795, 'Claim', 'End_Cut')), ((651, 717), (619, 663, 'Premise', 'Start_Cut'))]
# 122 [((659, 720), (694, 795, 'Claim', 'End_Cut')), ((659, 720), (619, 663, 'Premise', 'Start_Cut'))]
# 123 [((663, 726), (694, 795, 'Claim', 'End_Cut'))]
# 124 [((665, 727), (694, 795, 'Claim', 'End_Cut'))]
# 125 [((668, 738), (694, 795, 'Claim', 'End_Cut'))]
# 126 [((671, 745), (694, 795, 'Claim', 'End_Cut'))]
# 127 [((673, 751), (694, 795, 'Claim', 'End_Cut'))]
# 128 [((677, 752), (694, 795, 'Claim', 'End_Cut'))]
# 129 [((678, 756), (694, 795, 'Claim', 'End_Cut'))]
# 130 [((684, 767), (694, 795, 'Claim', 'End_Cut'))]
# 131 [((689, 772), (694, 795, 'Claim', 'End_Cut'))]
# 132 [((694, 782), (694, 795, 'Claim', 'End_Cut'))]
# 133 [((701, 795), (694, 795, 'Claim', 'Start_Cut'))]
# 134 [((705, 796), (694, 795, 'Claim', 'Start_Cut'))]
# 135 [((709, 800), (694, 795, 'Claim', 'Start_Cut'))]
# 136 [((718, 809), (694, 795, 'Claim', 'Start_Cut'))]
# 137 [((721, 810), (694, 795, 'Claim', 'Start_Cut'))]
# 138 [((726, 818), (694, 795, 'Claim', 'Start_Cut')), ((726, 818), (811, 886, 'Premise', 'End_Cut'))]
# 139 [((728, 828), (694, 795, 'Claim', 'Start_Cut')), ((728, 828), (811, 886, 'Premise', 'End_Cut'))]
# 140 [((739, 833), (694, 795, 'Claim', 'Start_Cut')), ((739, 833), (811, 886, 'Premise', 'End_Cut'))]
# 141 [((746, 839), (694, 795, 'Claim', 'Start_Cut')), ((746, 839), (811, 886, 'Premise', 'End_Cut'))]
# 142 [((751, 847), (694, 795, 'Claim', 'Start_Cut')), ((751, 847), (811, 886, 'Premise', 'End_Cut'))]
# 143 [((753, 852), (694, 795, 'Claim', 'Start_Cut')), ((753, 852), (811, 886, 'Premise', 'End_Cut'))]
# 144 [((757, 853), (694, 795, 'Claim', 'Start_Cut')), ((757, 853), (811, 886, 'Premise', 'End_Cut'))]
# 145 [((768, 859), (694, 795, 'Claim', 'Start_Cut')), ((768, 859), (811, 886, 'Premise', 'End_Cut'))]
# 146 [((773, 865), (694, 795, 'Claim', 'Start_Cut')), ((773, 865), (811, 886, 'Premise', 'End_Cut'))]
# 147 [((783, 868), (694, 795, 'Claim', 'Start_Cut')), ((783, 868), (811, 886, 'Premise', 'End_Cut'))]
# 148 [((795, 875), (811, 886, 'Premise', 'End_Cut'))]
# 149 [((797, 886), (811, 886, 'Premise', 'Full'))]
# 150 [((801, 887), (811, 886, 'Premise', 'Full'))]
# 151 [((809, 889), (811, 886, 'Premise', 'Full')), ((809, 889), (888, 973, 'Premise', 'End_Cut'))]
# 152 [((811, 897), (811, 886, 'Premise', 'Full')), ((811, 897), (888, 973, 'Premise', 'End_Cut'))]
# 153 [((819, 905), (811, 886, 'Premise', 'Start_Cut')), ((819, 905), (888, 973, 'Premise', 'End_Cut'))]
# 154 [((829, 908), (811, 886, 'Premise', 'Start_Cut')), ((829, 908), (888, 973, 'Premise', 'End_Cut'))]
# 155 [((834, 912), (811, 886, 'Premise', 'Start_Cut')), ((834, 912), (888, 973, 'Premise', 'End_Cut'))]
# 156 [((840, 918), (811, 886, 'Premise', 'Start_Cut')), ((840, 918), (888, 973, 'Premise', 'End_Cut'))]
# 157 [((848, 921), (811, 886, 'Premise', 'Start_Cut')), ((848, 921), (888, 973, 'Premise', 'End_Cut'))]
# 158 [((852, 928), (811, 886, 'Premise', 'Start_Cut')), ((852, 928), (888, 973, 'Premise', 'End_Cut'))]
# 159 [((854, 934), (811, 886, 'Premise', 'Start_Cut')), ((854, 934), (888, 973, 'Premise', 'End_Cut'))]
# 160 [((860, 935), (811, 886, 'Premise', 'Start_Cut')), ((860, 935), (888, 973, 'Premise', 'End_Cut'))]
# 161 [((866, 939), (811, 886, 'Premise', 'Start_Cut')), ((866, 939), (888, 973, 'Premise', 'End_Cut'))]
# 162 [((869, 943), (811, 886, 'Premise', 'Start_Cut')), ((869, 943), (888, 973, 'Premise', 'End_Cut'))]
# 163 [((876, 945), (811, 886, 'Premise', 'Start_Cut')), ((876, 945), (888, 973, 'Premise', 'End_Cut'))]
# 164 [((886, 949), (888, 973, 'Premise', 'End_Cut'))]
# 165 [((888, 950), (888, 973, 'Premise', 'End_Cut'))]
# 166 [((890, 954), (888, 973, 'Premise', 'Both_Sides_Cut'))]
# 167 [((898, 962), (888, 973, 'Premise', 'Both_Sides_Cut'))]
# 168 [((906, 966), (888, 973, 'Premise', 'Both_Sides_Cut'))]
# 169 [((909, 968), (888, 973, 'Premise', 'Both_Sides_Cut'))]
# 170 [((913, 973), (888, 973, 'Premise', 'Start_Cut'))]
# 171 [((919, 974), (888, 973, 'Premise', 'Start_Cut'))]
# 172 [((922, 975), (888, 973, 'Premise', 'Start_Cut'))]
# 173 [((929, 982), (888, 973, 'Premise', 'Start_Cut'))]
# 174 [((934, 983), (888, 973, 'Premise', 'Start_Cut'))]
# 175 [((936, 988), (888, 973, 'Premise', 'Start_Cut')), ((936, 988), (984, 1093, 'Claim', 'End_Cut'))]
# 176 [((940, 995), (888, 973, 'Premise', 'Start_Cut')), ((940, 995), (984, 1093, 'Claim', 'End_Cut'))]
# 177 [((944, 999), (888, 973, 'Premise', 'Start_Cut')), ((944, 999), (984, 1093, 'Claim', 'End_Cut'))]
# 178 [((946, 1003), (888, 973, 'Premise', 'Start_Cut')), ((946, 1003), (984, 1093, 'Claim', 'End_Cut'))]
# 179 [((949, 1007), (888, 973, 'Premise', 'Start_Cut')), ((949, 1007), (984, 1093, 'Claim', 'End_Cut'))]
# 180 [((950, 1018), (888, 973, 'Premise', 'Start_Cut')), ((950, 1018), (984, 1093, 'Claim', 'End_Cut'))]
# 181 [((955, 1021), (888, 973, 'Premise', 'Start_Cut')), ((955, 1021), (984, 1093, 'Claim', 'End_Cut'))]
# 182 [((963, 1028), (888, 973, 'Premise', 'Start_Cut')), ((963, 1028), (984, 1093, 'Claim', 'End_Cut'))]
# 183 [((967, 1033), (888, 973, 'Premise', 'Start_Cut')), ((967, 1033), (984, 1093, 'Claim', 'End_Cut'))]
# 184 [((969, 1037), (888, 973, 'Premise', 'Start_Cut')), ((969, 1037), (984, 1093, 'Claim', 'End_Cut'))]
# 185 [((973, 1043), (984, 1093, 'Claim', 'End_Cut'))]
# 186 [((974, 1046), (984, 1093, 'Claim', 'End_Cut'))]
# 187 [((975, 1057), (984, 1093, 'Claim', 'End_Cut'))]
# 188 [((982, 1066), (984, 1093, 'Claim', 'End_Cut'))]
# 189 [((984, 1069), (984, 1093, 'Claim', 'End_Cut'))]
# 190 [((989, 1075), (984, 1093, 'Claim', 'Both_Sides_Cut'))]
# 191 [((996, 1084), (984, 1093, 'Claim', 'Both_Sides_Cut'))]
# 192 [((1000, 1088), (984, 1093, 'Claim', 'Both_Sides_Cut'))]
# 193 [((1004, 1093), (984, 1093, 'Claim', 'Start_Cut'))]
# 194 [((1008, 1094), (984, 1093, 'Claim', 'Start_Cut'))]
# 195 [((1019, 1099), (984, 1093, 'Claim', 'Start_Cut')), ((1019, 1099), (1095, 1239, 'Premise', 'End_Cut'))]
# 196 [((1022, 1106), (984, 1093, 'Claim', 'Start_Cut')), ((1022, 1106), (1095, 1239, 'Premise', 'End_Cut'))]
# 197 [((1029, 1114), (984, 1093, 'Claim', 'Start_Cut')), ((1029, 1114), (1095, 1239, 'Premise', 'End_Cut'))]
# 198 [((1034, 1119), (984, 1093, 'Claim', 'Start_Cut')), ((1034, 1119), (1095, 1239, 'Premise', 'End_Cut'))]
# 199 [((1038, 1125), (984, 1093, 'Claim', 'Start_Cut')), ((1038, 1125), (1095, 1239, 'Premise', 'End_Cut'))]
# 200 [((1044, 1130), (984, 1093, 'Claim', 'Start_Cut')), ((1044, 1130), (1095, 1239, 'Premise', 'End_Cut'))]
# 201 [((1047, 1132), (984, 1093, 'Claim', 'Start_Cut')), ((1047, 1132), (1095, 1239, 'Premise', 'End_Cut'))]
# 202 [((1058, 1136), (984, 1093, 'Claim', 'Start_Cut')), ((1058, 1136), (1095, 1239, 'Premise', 'End_Cut'))]
# 203 [((1067, 1145), (984, 1093, 'Claim', 'Start_Cut')), ((1067, 1145), (1095, 1239, 'Premise', 'End_Cut'))]
# 204 [((1070, 1149), (984, 1093, 'Claim', 'Start_Cut')), ((1070, 1149), (1095, 1239, 'Premise', 'End_Cut'))]
# 205 [((1076, 1158), (984, 1093, 'Claim', 'Start_Cut')), ((1076, 1158), (1095, 1239, 'Premise', 'End_Cut'))]
# 206 [((1085, 1162), (984, 1093, 'Claim', 'Start_Cut')), ((1085, 1162), (1095, 1239, 'Premise', 'End_Cut'))]
# 207 [((1089, 1171), (984, 1093, 'Claim', 'Start_Cut')), ((1089, 1171), (1095, 1239, 'Premise', 'End_Cut'))]
# 208 [((1093, 1179), (1095, 1239, 'Premise', 'End_Cut'))]
# 209 [((1095, 1180), (1095, 1239, 'Premise', 'End_Cut'))]
# 210 [((1100, 1185), (1095, 1239, 'Premise', 'Both_Sides_Cut'))]
# 211 [((1107, 1188), (1095, 1239, 'Premise', 'Both_Sides_Cut'))]
# 212 [((1115, 1193), (1095, 1239, 'Premise', 'Both_Sides_Cut'))]
# 213 [((1120, 1197), (1095, 1239, 'Premise', 'Both_Sides_Cut'))]
# 214 [((1126, 1207), (1095, 1239, 'Premise', 'Both_Sides_Cut'))]
# 215 [((1131, 1210), (1095, 1239, 'Premise', 'Both_Sides_Cut'))]
# 216 [((1133, 1219), (1095, 1239, 'Premise', 'Both_Sides_Cut'))]
# 217 [((1137, 1220), (1095, 1239, 'Premise', 'Both_Sides_Cut'))]
# 218 [((1146, 1225), (1095, 1239, 'Premise', 'Both_Sides_Cut'))]
# 219 [((1150, 1226), (1095, 1239, 'Premise', 'Both_Sides_Cut'))]
# 220 [((1159, 1230), (1095, 1239, 'Premise', 'Both_Sides_Cut'))]
# 221 [((1163, 1231), (1095, 1239, 'Premise', 'Both_Sides_Cut'))]
# 222 [((1172, 1239), (1095, 1239, 'Premise', 'Start_Cut'))]
# 223 [((1179, 1240), (1095, 1239, 'Premise', 'Start_Cut'))]
# 224 [((1181, 1244), (1095, 1239, 'Premise', 'Start_Cut'))]
# 225 [((1186, 1247), (1095, 1239, 'Premise', 'Start_Cut'))]
# 226 [((1189, 1252), (1095, 1239, 'Premise', 'Start_Cut'))]
# 227 [((1194, 1260), (1095, 1239, 'Premise', 'Start_Cut'))]
# 228 [((1198, 1261), (1095, 1239, 'Premise', 'Start_Cut'))]
# 229 [((1208, 1266), (1095, 1239, 'Premise', 'Start_Cut')), ((1208, 1266), (1262, 1299, 'Premise', 'End_Cut'))]
# 230 [((1211, 1271), (1095, 1239, 'Premise', 'Start_Cut')), ((1211, 1271), (1262, 1299, 'Premise', 'End_Cut'))]
# 231 [((1219, 1276), (1095, 1239, 'Premise', 'Start_Cut')), ((1219, 1276), (1262, 1299, 'Premise', 'End_Cut'))]
# 232 [((1221, 1278), (1095, 1239, 'Premise', 'Start_Cut')), ((1221, 1278), (1262, 1299, 'Premise', 'End_Cut'))]
# 233 [((1225, 1282), (1095, 1239, 'Premise', 'Start_Cut')), ((1225, 1282), (1262, 1299, 'Premise', 'End_Cut'))]
# 234 [((1227, 1289), (1095, 1239, 'Premise', 'Start_Cut')), ((1227, 1289), (1262, 1299, 'Premise', 'End_Cut'))]
# 235 [((1230, 1292), (1095, 1239, 'Premise', 'Start_Cut')), ((1230, 1292), (1262, 1299, 'Premise', 'End_Cut'))]
# 236 [((1232, 1299), (1095, 1239, 'Premise', 'Start_Cut')), ((1232, 1299), (1262, 1299, 'Premise', 'Full'))]
# 237 [((1239, 1307), (1262, 1299, 'Premise', 'Full'))]
# 238 [((1241, 1312), (1262, 1299, 'Premise', 'Full')), ((1241, 1312), (1308, 1390, 'Premise', 'End_Cut'))]
# 239 [((1245, 1317), (1262, 1299, 'Premise', 'Full')), ((1245, 1317), (1308, 1390, 'Premise', 'End_Cut'))]
# 240 [((1248, 1321), (1262, 1299, 'Premise', 'Full')), ((1248, 1321), (1308, 1390, 'Premise', 'End_Cut'))]
# 241 [((1253, 1325), (1262, 1299, 'Premise', 'Full')), ((1253, 1325), (1308, 1390, 'Premise', 'End_Cut'))]
# 242 [((1260, 1330), (1262, 1299, 'Premise', 'Full')), ((1260, 1330), (1308, 1390, 'Premise', 'End_Cut'))]
# 243 [((1262, 1338), (1262, 1299, 'Premise', 'Full')), ((1262, 1338), (1308, 1390, 'Premise', 'End_Cut'))]
# 244 [((1267, 1347), (1262, 1299, 'Premise', 'Start_Cut')), ((1267, 1347), (1308, 1390, 'Premise', 'End_Cut'))]
# 245 [((1272, 1348), (1262, 1299, 'Premise', 'Start_Cut')), ((1272, 1348), (1308, 1390, 'Premise', 'End_Cut'))]
# 246 [((1277, 1353), (1262, 1299, 'Premise', 'Start_Cut')), ((1277, 1353), (1308, 1390, 'Premise', 'End_Cut'))]
# 247 [((1279, 1358), (1262, 1299, 'Premise', 'Start_Cut')), ((1279, 1358), (1308, 1390, 'Premise', 'End_Cut'))]
# 248 [((1283, 1363), (1262, 1299, 'Premise', 'Start_Cut')), ((1283, 1363), (1308, 1390, 'Premise', 'End_Cut'))]
# 249 [((1290, 1366), (1262, 1299, 'Premise', 'Start_Cut')), ((1290, 1366), (1308, 1390, 'Premise', 'End_Cut'))]
# 250 [((1293, 1371), (1262, 1299, 'Premise', 'Start_Cut')), ((1293, 1371), (1308, 1390, 'Premise', 'End_Cut'))]
# 251 [((1300, 1375), (1308, 1390, 'Premise', 'End_Cut'))]
# 252 [((1308, 1381), (1308, 1390, 'Premise', 'End_Cut'))]
# 253 [((1313, 1390), (1308, 1390, 'Premise', 'Start_Cut'))]
# 254 [((1318, 1391), (1308, 1390, 'Premise', 'Start_Cut'))]
# 255 [((1322, 1392), (1308, 1390, 'Premise', 'Start_Cut'))]
# 256 [((1326, 1394), (1308, 1390, 'Premise', 'Start_Cut'))]
# 257 [((1331, 1405), (1308, 1390, 'Premise', 'Start_Cut'))]
# 258 [((1339, 1406), (1308, 1390, 'Premise', 'Start_Cut'))]
# 259 [((1347, 1415), (1308, 1390, 'Premise', 'Start_Cut'))]
# 260 [((1349, 1418), (1416, 1478, 'Claim', 'End_Cut')), ((1349, 1418), (1308, 1390, 'Premise', 'Start_Cut'))]
# 261 [((1354, 1421), (1416, 1478, 'Claim', 'End_Cut')), ((1354, 1421), (1308, 1390, 'Premise', 'Start_Cut'))]
# 262 [((1359, 1432), (1416, 1478, 'Claim', 'End_Cut')), ((1359, 1432), (1308, 1390, 'Premise', 'Start_Cut'))]
# 263 [((1364, 1437), (1416, 1478, 'Claim', 'End_Cut')), ((1364, 1437), (1308, 1390, 'Premise', 'Start_Cut'))]
# 264 [((1367, 1446), (1416, 1478, 'Claim', 'End_Cut')), ((1367, 1446), (1308, 1390, 'Premise', 'Start_Cut'))]
# 265 [((1372, 1449), (1416, 1478, 'Claim', 'End_Cut')), ((1372, 1449), (1308, 1390, 'Premise', 'Start_Cut'))]
# 266 [((1376, 1451), (1416, 1478, 'Claim', 'End_Cut')), ((1376, 1451), (1308, 1390, 'Premise', 'Start_Cut'))]
# 267 [((1382, 1459), (1416, 1478, 'Claim', 'End_Cut')), ((1382, 1459), (1308, 1390, 'Premise', 'Start_Cut'))]
# 268 [((1390, 1464), (1416, 1478, 'Claim', 'End_Cut'))]
# 269 [((1391, 1467), (1416, 1478, 'Claim', 'End_Cut'))]
# 270 [((1392, 1473), (1416, 1478, 'Claim', 'End_Cut'))]
# 271 [((1395, 1478), (1416, 1478, 'Claim', 'Full'))]
# 272 [((1405, 1479), (1416, 1478, 'Claim', 'Full'))]
# 273 [((1407, 1482), (1480, 1530, 'Claim', 'End_Cut')), ((1407, 1482), (1416, 1478, 'Claim', 'Full'))]
# 274 [((1416, 1488), (1480, 1530, 'Claim', 'End_Cut')), ((1416, 1488), (1416, 1478, 'Claim', 'Full'))]
# 275 [((1419, 1492), (1480, 1530, 'Claim', 'End_Cut')), ((1419, 1492), (1416, 1478, 'Claim', 'Start_Cut'))]
# 276 [((1422, 1496), (1480, 1530, 'Claim', 'End_Cut')), ((1422, 1496), (1416, 1478, 'Claim', 'Start_Cut'))]
# 277 [((1433, 1500), (1480, 1530, 'Claim', 'End_Cut')), ((1433, 1500), (1416, 1478, 'Claim', 'Start_Cut'))]
# 278 [((1438, 1505), (1480, 1530, 'Claim', 'End_Cut')), ((1438, 1505), (1416, 1478, 'Claim', 'Start_Cut'))]
# 279 [((1447, 1506), (1480, 1530, 'Claim', 'End_Cut')), ((1447, 1506), (1416, 1478, 'Claim', 'Start_Cut'))]
# 280 [((1450, 1517), (1480, 1530, 'Claim', 'End_Cut')), ((1450, 1517), (1416, 1478, 'Claim', 'Start_Cut'))]
# 281 [((1452, 1521), (1480, 1530, 'Claim', 'End_Cut')), ((1452, 1521), (1416, 1478, 'Claim', 'Start_Cut'))]
# 282 [((1460, 1530), (1480, 1530, 'Claim', 'Full')), ((1460, 1530), (1416, 1478, 'Claim', 'Start_Cut'))]
# 283 [((1465, 1531), (1480, 1530, 'Claim', 'Full')), ((1465, 1531), (1416, 1478, 'Claim', 'Start_Cut'))]
# 284 [((1468, 1538), (1480, 1530, 'Claim', 'Full')), ((1468, 1538), (1416, 1478, 'Claim', 'Start_Cut'))]
# 285 [((1474, 1545), (1480, 1530, 'Claim', 'Full')), ((1474, 1545), (1416, 1478, 'Claim', 'Start_Cut'))]
# 286 [((1478, 1551), (1480, 1530, 'Claim', 'Full'))]
# 287 [((1480, 1555), (1480, 1530, 'Claim', 'Full'))]
# 288 [((1483, 1558), (1480, 1530, 'Claim', 'Start_Cut'))]
# 289 [((1489, 1562), (1480, 1530, 'Claim', 'Start_Cut'))]
# 290 [((1493, 1565), (1480, 1530, 'Claim', 'Start_Cut'))]
# 291 [((1497, 1574), (1480, 1530, 'Claim', 'Start_Cut'))]
# 292 [((1501, 1577), (1480, 1530, 'Claim', 'Start_Cut'))]
# 293 [((1505, 1582), (1480, 1530, 'Claim', 'Start_Cut'))]
# 294 [((1507, 1585), (1480, 1530, 'Claim', 'Start_Cut'))]
# 295 [((1518, 1588), (1480, 1530, 'Claim', 'Start_Cut'))]
# 296 [((1522, 1598), (1480, 1530, 'Claim', 'Start_Cut'))]

# %%
def is_adu(unit_start, unit_end, adu_start, adu_end):
    
    if adu_start<=unit_start and adu_end <=unit_start:
        # ADU comes before UNIT
        return False
    elif adu_start>=unit_end and adu_end >=unit_end:
        # ADU comes after UNIT
        return False
    else:
        if adu_start >= unit_start and adu_end <= unit_end:
            #print("Fully Contains ADU")
            return "Full"
        elif adu_start <= unit_start and adu_end <=unit_end:
            
            #print("ADU start is cut")
            return "Start_Cut"
        elif adu_start >= unit_start and adu_end >= unit_end:
            # End of ADU is after UNIT
            return "End_Cut"

        elif adu_start <= unit_start and adu_end >= unit_end:

            # UNIT is smaller than ADU, ADU start and end are cut
            return "Both_Sides_Cut"

# %%
# EXTENSION WORKING HERE

def get_label_and_error(unit, error_function='percentage_correctness'):
    """
    Inputs: unit
    
    Outputs: label for the unit and segmentation error
    
    """
    
    def overlap_case(unit_start, unit_end, adu_start, adu_end):
        if adu_start >= unit_start and adu_end <= unit_end:
            # Case 1, ADU is fully contained in UNIT
            return 1
        
        elif adu_start <= unit_start and adu_end <=unit_end and adu_end>=unit_start:

            # Case 2, ADU starts before UNIT, start(Left) of ADU is cut
            return 2
        
        elif adu_start >= unit_start and adu_end >= unit_end and adu_start<unit_end:
            
            # Case 3, ADU starts after UNIT, end(Right) of ADU is cut
            return 3

        elif adu_start < unit_start and adu_end > unit_end:

            # Case 4, ADU starts before UNIT and ends after UNIT, both sides of ADU are cut
            return 4
        
        else: 
            # ADU does not overlap with UNIT
            return False
        
    
    def percentage_correctness(unit, adu_start, adu_end, overlap_case):
        
        if overlap_case==2:
            adu_start = unit._.idx_start
        if overlap_case==3:
            adu_end = unit._.idx_end
        
        adu = unit.doc.char_span(adu_start, adu_end, alignment_mode='expand')
        
        unit_ntokens = len(unit)
        adu_ntokens = len(adu)
        pct_correct = (unit_ntokens - adu_ntokens)/unit_ntokens
        
        return pct_correct
    
    def extended_accuracy(unit, adu_start, adu_end, overlap_case):
        # Compares number of tokens to get the the correct ADU in proportional with UNIT length
        
        adu = unit.doc.char_span(adu_start, adu_end, alignment_mode='expand')
        
        unit_ntokens = len(unit)
        adu_ntokens = len(adu)
        diff_ntokens = np.abs(unit_ntokens - adu_ntokens)
        
        return 1/((diff_ntokens+1)**(np.log2(diff_ntokens+1)/np.log2(unit_ntokens+1)))
        
        
    if error_function.lower() == 'percentage_correctness':
        err_func = percentage_correctness
    elif error_function.lower() == 'extended_accuracy':
        err_func = extended_accuracy
    
    unit_start = unit._.idx_start
    unit_end = unit._.idx_end

    essay_id = u.doc._.essay_id

    # DataFrame containing ADUs indices & labels, filtered for current essay_id
    adus_doc = adus[adus['essay_id'] == essay_id]
    

    
    label_and_error = [(row['ADU_type'], err_func(unit, row['start_ind'],row['end_ind'], 
                     overlap_case(unit_start, unit_end,row['start_ind'], row['end_ind']))) 
                     for row_ind, row in adus_doc.iterrows() 
                     if unit_start <= row['end_ind'] and unit_end >= row['start_ind']]
    
#     # Contains information of the ADUs that overlap with the UNIT
#     # Structure: (adu_start, adu_end, overlap_case, ADU_type)
#     overlap_adus = [(row['start_ind'],
#                      row['end_ind'], 
#                      overlap_case(unit_start, unit_end,row['start_ind'], row['end_ind']), 
#                      row['ADU_type']) 
#                      for row_ind, row in adus_doc.iterrows()
#           if unit_start <= row['end_ind'] and unit_end >= row['start_ind']]

    return label_and_error

# %%
get_label_and_error(units[163], error_function='extended_accuracy')
# Out:
# [('Premise', 0.5), ('Premise', 0.3141427559625005)]

# %%
def extended_acc(d, s):

    return 1/((d+1)**(np.log2(d+1)/np.log2(s+1)))


# unit_start = units[54]._.idx_start
# unit_end = units[54]._.idx_end

adu = doc.char_span(311,373, alignment_mode='expand')
unit = units[54]
# Out:
# true.
# First, using computer constantly has bad influence on children's eyes

# %%
# Out:
# (4,
#  'End_Cut',
#
#  First, using computer constantly has bad influence on children's eyes. When,
#  When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted)

# %%
u123 = segmentation(doc)
# Out:
# [Computer has negative effects to children
#  ,
#  Nowadays, thanks to the development of technology, computer is now indispensable to life.,
#  Some people think that computer is good for children and it should be used daily by children but some others think differently.,
#  In my opinion, the latter opinion is true.,
#
#  First, using computer constantly has bad influence on children's eyes.,
#  When they concentrate on computer for too long, their eyes will get tired, which is the main reason for some eyes problems, typically shortsighted.,
#  Moreover, children who play games too much on computer can seriously lack communicating skills, they will know little about the outside life.,
#  It is a well-known fact that people who are addicted to games, especially online games, can eventually bear dangerous consequences.,
#  For instance, several teenagers play games without rest, which leads to health depression, a typical example is the death of Korean gamer, who had a non-stop playing for 3 days.,
#
#  Finally, even people who are not interested in online game can still be negatively affected by using computer too much.,
#  Some social surveys have shown that a few children use computer for studying purpose, most of them are attracted by facebook, blog, etc. instead.,
#  Due to this neglect, they will have a bad result in school because when they can not live without internet, they will have no time for their studying.,
#  In conclusion, although it is undeniable that computer is a crucial part of human life, it still has its bad side, especially for children.,
#  People should learn how to use it properly to make it an effective tool because computer should be used not only for entertaining but also for working and studying purpose.]

# %%
def segmentation_error(unit_start, unit_end, adu_start, adu_end, mode='extended_acc'):

    def extended_acc(d, s):

        return 1/((d+1)**(np.log2(d+1)/np.log2(s+1)))

    adu = doc.char_span(adu_start, adu_end, alignment_mode = 'expand')
    unit = doc.char_span(unit_start, unit_end) 
    
    unit_ntokens = len(unit)
    adu_ntokens = len(adu)
    
    d = np.abs(unit_ntokens - adu_ntokens)
    
    if adu_start<=unit_start and adu_end <=unit_start:
        # ADU comes before UNIT
        return False
    elif adu_start>=unit_end and adu_end >=unit_end:
        # ADU comes after UNIT
        return False
    else:
        if adu_start >= unit_start and adu_end <= unit_end:
            #print("Fully Contains ADU")
            error = extended_acc(d, unit_ntokens)
            cut_type "Full"
        elif adu_start <= unit_start and adu_end <=unit_end:
            
            #print("ADU start is cut")
            return "Start_Cut"
        elif adu_start >= unit_start and adu_end >= unit_end:
            # End of ADU is Cut
            return "End_Cut"

        elif adu_start <= unit_start and adu_end >= unit_end:

            # UNIT is smaller than ADU, ADU start and end are cut
            return "Both_Sides_Cut"
# Out:
#   File "C:\Users\Ashwin\AppData\Local\Temp/ipykernel_13064/507436367.py", line 25
#     cut_type "Full"
#              ^
# SyntaxError: invalid syntax

# %%
def verbose_print(units):
    # Detailed Printer
    for i, u in enumerate(units):
            span_start = u[0].idx
            span_end = u[-1].idx  + len(u[-1])

            lis = [((span_start, span_end),(row['start_ind'], row['end_ind'], row['ADU_type'],is_adu(span_start, span_end, row['start_ind'] ,row['end_ind']))) for row_ind,row in adu24.iterrows() if is_adu(span_start, span_end, row['start_ind'] ,row['end_ind'])]
            if len(lis)>0:
                print(i)
                print(lis,"\n")
                print("UNIT:",u,"\n")
                for ind, adu in enumerate(lis):

                    #print(adu[1][2].upper()+':',adu[1][0:2])
                    #print(doc.char_span(*adu[1][0:2]), "\n")
                    label = adu[1][2].upper() 
                    adu_range = adu[1][0:2]
                    adu_status = adu[1][3]
                    print(f'ADU #{ind+1}',label+':',*adu_range, adu_status)
                    print(doc.char_span(*adu_range), "\n")
                print("-----------------\n")

# %%
# INPUTS 
essays = pd.read_csv("../data/output_csv/essays.csv")
adus = pd.read_csv("../data/output_csv/adus.csv")

###### TEST
in_text = essays.iloc[23].text
doc = nlp(in_text)
doc._.essay_id = essays.iloc[23]['essay_id']
adu24 = adus[adus['essay_id'] == doc._.essay_id]
units=segmentation(doc, mode='n_grams', n_grams=15)
#units=segmentation(doc, mode='sentence')

# %%
def get_label_error(unit):
    
        essay_id = unit.doc._.essay_id
        unit_start = unit[0].idx
        #  + len(unit[-1]) to get to the end of the last word
        unit_end = unit[-1].idx  + len(unit[-1])
        adus_iter = adus[adus['essay_id'] == essay_id ].iterrows()
        adus_list = [ (unit._.index_in_doc, is_adu(unit_start, unit_end, row['start_ind'], row['end_ind']) , doc.char_span(unit_start, unit_end), doc.char_span(row['start_ind'], row['end_ind'])) for i, row in adus_iter if is_adu(unit_start, unit_end, row['start_ind'], row['end_ind'])]
        
        return adus_list
Span.set_extension('label_error', force=True, getter=get_label_error)

# %%
# for i, u in enumerate(units):
#     if u._.label:
#         span_start = u[0].idx
#         span_end = u[-1].idx  + len(u[-1])
        
#         lis = [((span_start, span_end),(row['start_ind'], row['end_ind'], row['ADU_type'],row_ind)) for row_ind,row in adu24.iterrows() if span_start<= row['start_ind'] and span_end>= row['end_ind']]
#         print(i,'--------------------------')
#         print(lis,"\n")
        
#         print("UNIT:",span_start, span_end)
#         print(u,"\n")
        
#         for adu in lis:
            
#             #print(adu[1][2].upper()+':',adu[1][0:2])
#             #print(doc.char_span(*adu[1][0:2]), "\n")
#             label = adu[1][2].upper() 
#             adu_range = adu[1][0:2]
#             print(label+':',*adu_range)
#             print(doc.char_span(*adu_range), "\n")
            
            
#         #print(i ,len(lis) ,lis[0]['ADU_text'], lis[0]['ADU_type'],"\n", lis[-1]['ADU_text'],lis[-1]['ADU_type'])

# %%
for i, u in enumerate(units):
        span_start = u[0].idx
        span_end = u[-1].idx  + len(u[-1])
        
        lis = [((span_start, span_end),(row['start_ind'], row['end_ind'], row['ADU_type'],row_ind)) for row_ind,row in adu24.iterrows() if span_start<= row['start_ind'] and span_end>= row['end_ind']]
        
        print(i,'--------------------------')
        print(lis,"\n")
        
        print("UNIT:",span_start, span_end)
        print(u,"\n")
        
        for adu in lis:
            
            #print(adu[1][2].upper()+':',adu[1][0:2])
            #print(doc.char_span(*adu[1][0:2]), "\n")
            label = adu[1][2].upper() 
            adu_range = adu[1][0:2]
            print(label+':',*adu_range)
            print(doc.char_span(*adu_range), "\n")
            
            
        #print(i ,len(lis) ,lis[0]['ADU_text'], lis[0]['ADU_type'],"\n", lis[-1]['ADU_text'],lis[-1]['ADU_type'])
# Out:
# 0 --------------------------
# []
#
# UNIT: 0 59
# Computer has negative effects to children
#
# Nowadays, thanks
#
# 1 --------------------------
# []
#
# UNIT: 9 62
# has negative effects to children
#
# Nowadays, thanks to
#
# 2 --------------------------
# []
#
# UNIT: 13 66
# negative effects to children
#
# Nowadays, thanks to the
#
# 3 --------------------------
# []
#
# UNIT: 22 78
# effects to children
#
# Nowadays, thanks to the development
#
# 4 --------------------------
# []
#
# UNIT: 30 81
# to children
#
# Nowadays, thanks to the development of
#
# 5 --------------------------
# []
#
# UNIT: 33 92
# children
#
# Nowadays, thanks to the development of technology
#
# 6 --------------------------
# []
#
# UNIT: 41 93
#
#
# Nowadays, thanks to the development of technology,
#
# 7 --------------------------
# []
#
# UNIT: 43 102
# Nowadays, thanks to the development of technology, computer
#
# 8 --------------------------
# []
#
# UNIT: 51 105
# , thanks to the development of technology, computer is
#
# 9 --------------------------
# []
#
# UNIT: 53 109
# thanks to the development of technology, computer is now
#
# 10 --------------------------
# []
#
# UNIT: 60 123
# to the development of technology, computer is now indispensable
#
# 11 --------------------------
# []
#
# UNIT: 63 126
# the development of technology, computer is now indispensable to
#
# 12 --------------------------
# []
#
# UNIT: 67 131
# development of technology, computer is now indispensable to life
#
# 13 --------------------------
# []
#
# UNIT: 79 132
# of technology, computer is now indispensable to life.
#
# 14 --------------------------
# []
#
# UNIT: 82 137
# technology, computer is now indispensable to life. Some
#
# 15 --------------------------
# []
#
# UNIT: 92 144
# , computer is now indispensable to life. Some people
#
# 16 --------------------------
# []
#
# UNIT: 94 150
# computer is now indispensable to life. Some people think
#
# 17 --------------------------
# []
#
# UNIT: 103 155
# is now indispensable to life. Some people think that
#
# 18 --------------------------
# []
#
# UNIT: 106 164
# now indispensable to life. Some people think that computer
#
# 19 --------------------------
# []
#
# UNIT: 110 167
# indispensable to life. Some people think that computer is
#
# 20 --------------------------
# []
#
# UNIT: 124 172
# to life. Some people think that computer is good
#
# 21 --------------------------
# []
#
# UNIT: 127 176
# life. Some people think that computer is good for
#
# 22 --------------------------
# []
#
# UNIT: 131 185
# . Some people think that computer is good for children
#
# 23 --------------------------
# []
#
# UNIT: 133 189
# Some people think that computer is good for children and
#
# 24 --------------------------
# []
#
# UNIT: 138 192
# people think that computer is good for children and it
#
# 25 --------------------------
# []
#
# UNIT: 145 199
# think that computer is good for children and it should
#
# 26 --------------------------
# []
#
# UNIT: 151 202
# that computer is good for children and it should be
#
# 27 --------------------------
# []
#
# UNIT: 156 207
# computer is good for children and it should be used
#
# 28 --------------------------
# []
#
# UNIT: 165 213
# is good for children and it should be used daily
#
# 29 --------------------------
# []
#
# UNIT: 168 216
# good for children and it should be used daily by
#
# 30 --------------------------
# []
#
# UNIT: 173 225
# for children and it should be used daily by children
#
# 31 --------------------------
# []
#
# UNIT: 177 229
# children and it should be used daily by children but
#
# 32 --------------------------
# []
#
# UNIT: 186 234
# and it should be used daily by children but some
#
# 33 --------------------------
# []
#
# UNIT: 190 241
# it should be used daily by children but some others
#
# 34 --------------------------
# []
#
# UNIT: 193 247
# should be used daily by children but some others think
#
# 35 --------------------------
# []
#
# UNIT: 200 259
# be used daily by children but some others think differently
#
# 36 --------------------------
# []
#
# UNIT: 203 260
# used daily by children but some others think differently.
#
# 37 --------------------------
# []
#
# UNIT: 208 263
# daily by children but some others think differently. In
#
# 38 --------------------------
# []
#
# UNIT: 214 266
# by children but some others think differently. In my
#
# 39 --------------------------
# []
#
# UNIT: 217 274
# children but some others think differently. In my opinion
#
# 40 --------------------------
# []
#
# UNIT: 226 275
# but some others think differently. In my opinion,
#
# 41 --------------------------
# []
#
# UNIT: 230 279
# some others think differently. In my opinion, the
#
# 42 --------------------------
# []
#
# UNIT: 235 286
# others think differently. In my opinion, the latter
#
# 43 --------------------------
# []
#
# UNIT: 242 294
# think differently. In my opinion, the latter opinion
#
# 44 --------------------------
# []
#
# UNIT: 248 297
# differently. In my opinion, the latter opinion is
#
# 45 --------------------------
# []
#
# UNIT: 259 302
# . In my opinion, the latter opinion is true
#
# 46 --------------------------
# []
#
# UNIT: 261 303
# In my opinion, the latter opinion is true.
#
# 47 --------------------------
# []
#
# UNIT: 264 304
# my opinion, the latter opinion is true.
#
#
# 48 --------------------------
# []
#
# UNIT: 267 309
# opinion, the latter opinion is true.
# First
#
# 49 --------------------------
# []
#
# UNIT: 274 310
# , the latter opinion is true.
# First,
#
# 50 --------------------------
# []
#
# UNIT: 276 316
# the latter opinion is true.
# First, using
#
# 51 --------------------------
# []
#
# UNIT: 280 325
# latter opinion is true.
# First, using computer
#
# 52 --------------------------
# []
#
# UNIT: 287 336
# opinion is true.
# First, using computer constantly
#
# 53 --------------------------
# []
#
# UNIT: 295 340
# is true.
# First, using computer constantly has
#
# 54 --------------------------
# []
#
# UNIT: 298 344
# true.
# First, using computer constantly has bad
#
# 55 --------------------------
# []
#
# UNIT: 302 354
# .
# First, using computer constantly has bad influence
#
# 56 --------------------------
# []
#
# UNIT: 303 357
#
# First, using computer constantly has bad influence on
#
# 57 --------------------------
# []
#
# UNIT: 304 366
# First, using computer constantly has bad influence on children
#
# 58 --------------------------
# []
#
# UNIT: 309 368
# , using computer constantly has bad influence on children's
#
# 59 --------------------------
# [((311, 373), (311, 373, 'Claim', 340))]
#
# UNIT: 311 373
# using computer constantly has bad influence on children's eyes
#
# CLAIM: 311 373
# using computer constantly has bad influence on children's eyes
#
# 60 --------------------------
# []
#
# UNIT: 317 374
# computer constantly has bad influence on children's eyes.
#
# 61 --------------------------
# []
#
# UNIT: 326 379
# constantly has bad influence on children's eyes. When
#
# 62 --------------------------
# []
#
# UNIT: 337 384
# has bad influence on children's eyes. When they
#
# 63 --------------------------
# []
#
# UNIT: 341 396
# bad influence on children's eyes. When they concentrate
#
# 64 --------------------------
# []
#
# UNIT: 345 399
# influence on children's eyes. When they concentrate on
#
# 65 --------------------------
# []
#
# UNIT: 355 408
# on children's eyes. When they concentrate on computer
#
# 66 --------------------------
# []
#
# UNIT: 358 412
# children's eyes. When they concentrate on computer for
#
# 67 --------------------------
# []
#
# UNIT: 366 416
# 's eyes. When they concentrate on computer for too
#
# 68 --------------------------
# []
#
# UNIT: 369 421
# eyes. When they concentrate on computer for too long
#
# 69 --------------------------
# []
#
# UNIT: 373 422
# . When they concentrate on computer for too long,
#
# 70 --------------------------
# []
#
# UNIT: 375 428
# When they concentrate on computer for too long, their
#
# 71 --------------------------
# []
#
# UNIT: 380 433
# they concentrate on computer for too long, their eyes
#
# 72 --------------------------
# []
#
# UNIT: 385 438
# concentrate on computer for too long, their eyes will
#
# 73 --------------------------
# []
#
# UNIT: 397 442
# on computer for too long, their eyes will get
#
# 74 --------------------------
# []
#
# UNIT: 400 448
# computer for too long, their eyes will get tired
#
# 75 --------------------------
# []
#
# UNIT: 409 449
# for too long, their eyes will get tired,
#
# 76 --------------------------
# []
#
# UNIT: 413 455
# too long, their eyes will get tired, which
#
# 77 --------------------------
# []
#
# UNIT: 417 458
# long, their eyes will get tired, which is
#
# 78 --------------------------
# []
#
# UNIT: 421 462
# , their eyes will get tired, which is the
#
# 79 --------------------------
# []
#
# UNIT: 423 467
# their eyes will get tired, which is the main
#
# 80 --------------------------
# []
#
# UNIT: 429 474
# eyes will get tired, which is the main reason
#
# 81 --------------------------
# []
#
# UNIT: 434 478
# will get tired, which is the main reason for
#
# 82 --------------------------
# []
#
# UNIT: 439 483
# get tired, which is the main reason for some
#
# 83 --------------------------
# []
#
# UNIT: 443 488
# tired, which is the main reason for some eyes
#
# 84 --------------------------
# []
#
# UNIT: 448 497
# , which is the main reason for some eyes problems
#
# 85 --------------------------
# []
#
# UNIT: 450 498
# which is the main reason for some eyes problems,
#
# 86 --------------------------
# []
#
# UNIT: 456 508
# is the main reason for some eyes problems, typically
#
# 87 --------------------------
# []
#
# UNIT: 459 521
# the main reason for some eyes problems, typically shortsighted
#
# 88 --------------------------
# []
#
# UNIT: 463 522
# main reason for some eyes problems, typically shortsighted.
#
# 89 --------------------------
# []
#
# UNIT: 468 523
# reason for some eyes problems, typically shortsighted.
#
#
# 90 --------------------------
# []
#
# UNIT: 475 531
# for some eyes problems, typically shortsighted.
# Moreover
#
# 91 --------------------------
# []
#
# UNIT: 479 532
# some eyes problems, typically shortsighted.
# Moreover,
#
# 92 --------------------------
# []
#
# UNIT: 484 541
# eyes problems, typically shortsighted.
# Moreover, children
#
# 93 --------------------------
# []
#
# UNIT: 489 545
# problems, typically shortsighted.
# Moreover, children who
#
# 94 --------------------------
# []
#
# UNIT: 497 550
# , typically shortsighted.
# Moreover, children who play
#
# 95 --------------------------
# []
#
# UNIT: 499 556
# typically shortsighted.
# Moreover, children who play games
#
# 96 --------------------------
# []
#
# UNIT: 509 560
# shortsighted.
# Moreover, children who play games too
#
# 97 --------------------------
# []
#
# UNIT: 521 565
# .
# Moreover, children who play games too much
#
# 98 --------------------------
# []
#
# UNIT: 522 568
#
# Moreover, children who play games too much on
#
# 99 --------------------------
# []
#
# UNIT: 523 577
# Moreover, children who play games too much on computer
#
# 100 --------------------------
# []
#
# UNIT: 531 581
# , children who play games too much on computer can
#
# 101 --------------------------
# []
#
# UNIT: 533 591
# children who play games too much on computer can seriously
#
# 102 --------------------------
# []
#
# UNIT: 542 596
# who play games too much on computer can seriously lack
#
# 103 --------------------------
# []
#
# UNIT: 546 610
# play games too much on computer can seriously lack communicating
#
# 104 --------------------------
# []
#
# UNIT: 551 617
# games too much on computer can seriously lack communicating skills
#
# 105 --------------------------
# []
#
# UNIT: 557 618
# too much on computer can seriously lack communicating skills,
#
# 106 --------------------------
# []
#
# UNIT: 561 623
# much on computer can seriously lack communicating skills, they
#
# 107 --------------------------
# []
#
# UNIT: 566 628
# on computer can seriously lack communicating skills, they will
#
# 108 --------------------------
# []
#
# UNIT: 569 633
# computer can seriously lack communicating skills, they will know
#
# 109 --------------------------
# []
#
# UNIT: 578 640
# can seriously lack communicating skills, they will know little
#
# 110 --------------------------
# []
#
# UNIT: 582 646
# seriously lack communicating skills, they will know little about
#
# 111 --------------------------
# []
#
# UNIT: 592 650
# lack communicating skills, they will know little about the
#
# 112 --------------------------
# []
#
# UNIT: 597 658
# communicating skills, they will know little about the outside
#
# 113 --------------------------
# [((611, 663), (619, 663, 'Premise', 350))]
#
# UNIT: 611 663
# skills, they will know little about the outside life
#
# PREMISE: 619 663
# they will know little about the outside life
#
# 114 --------------------------
# [((617, 664), (619, 663, 'Premise', 350))]
#
# UNIT: 617 664
# , they will know little about the outside life.
#
# PREMISE: 619 663
# they will know little about the outside life
#
# 115 --------------------------
# [((619, 667), (619, 663, 'Premise', 350))]
#
# UNIT: 619 667
# they will know little about the outside life. It
#
# PREMISE: 619 663
# they will know little about the outside life
#
# 116 --------------------------
# []
#
# UNIT: 624 670
# will know little about the outside life. It is
#
# 117 --------------------------
# []
#
# UNIT: 629 672
# know little about the outside life. It is a
#
# 118 --------------------------
# []
#
# UNIT: 634 677
# little about the outside life. It is a well
#
# 119 --------------------------
# []
#
# UNIT: 641 678
# about the outside life. It is a well-
#
# 120 --------------------------
# []
#
# UNIT: 647 683
# the outside life. It is a well-known
#
# 121 --------------------------
# []
#
# UNIT: 651 688
# outside life. It is a well-known fact
#
# 122 --------------------------
# []
#
# UNIT: 659 693
# life. It is a well-known fact that
#
# 123 --------------------------
# []
#
# UNIT: 663 700
# . It is a well-known fact that people
#
# 124 --------------------------
# []
#
# UNIT: 665 704
# It is a well-known fact that people who
#
# 125 --------------------------
# []
#
# UNIT: 668 708
# is a well-known fact that people who are
#
# 126 --------------------------
# []
#
# UNIT: 671 717
# a well-known fact that people who are addicted
#
# 127 --------------------------
# []
#
# UNIT: 673 720
# well-known fact that people who are addicted to
#
# 128 --------------------------
# []
#
# UNIT: 677 726
# -known fact that people who are addicted to games
#
# 129 --------------------------
# []
#
# UNIT: 678 727
# known fact that people who are addicted to games,
#
# 130 --------------------------
# []
#
# UNIT: 684 738
# fact that people who are addicted to games, especially
#
# 131 --------------------------
# []
#
# UNIT: 689 745
# that people who are addicted to games, especially online
#
# 132 --------------------------
# []
#
# UNIT: 694 751
# people who are addicted to games, especially online games
#
# 133 --------------------------
# []
#
# UNIT: 701 752
# who are addicted to games, especially online games,
#
# 134 --------------------------
# []
#
# UNIT: 705 756
# are addicted to games, especially online games, can
#
# 135 --------------------------
# []
#
# UNIT: 709 767
# addicted to games, especially online games, can eventually
#
# 136 --------------------------
# []
#
# UNIT: 718 772
# to games, especially online games, can eventually bear
#
# 137 --------------------------
# []
#
# UNIT: 721 782
# games, especially online games, can eventually bear dangerous
#
# 138 --------------------------
# []
#
# UNIT: 726 795
# , especially online games, can eventually bear dangerous consequences
#
# 139 --------------------------
# []
#
# UNIT: 728 796
# especially online games, can eventually bear dangerous consequences.
#
# 140 --------------------------
# []
#
# UNIT: 739 800
# online games, can eventually bear dangerous consequences. For
#
# 141 --------------------------
# []
#
# UNIT: 746 809
# games, can eventually bear dangerous consequences. For instance
#
# 142 --------------------------
# []
#
# UNIT: 751 810
# , can eventually bear dangerous consequences. For instance,
#
# 143 --------------------------
# []
#
# UNIT: 753 818
# can eventually bear dangerous consequences. For instance, several
# 144 --------------------------
# []
#
# UNIT: 757 828
# eventually bear dangerous consequences. For instance, several teenagers
#
# 145 --------------------------
# []
#
# UNIT: 768 833
# bear dangerous consequences. For instance, several teenagers play
#
# 146 --------------------------
# []
#
# UNIT: 773 839
# dangerous consequences. For instance, several teenagers play games
#
# 147 --------------------------
# []
#
# UNIT: 783 847
# consequences. For instance, several teenagers play games without
#
# 148 --------------------------
# []
#
# UNIT: 795 852
# . For instance, several teenagers play games without rest
#
# 149 --------------------------
# []
#
# UNIT: 797 853
# For instance, several teenagers play games without rest,
#
# 150 --------------------------
# []
#
# UNIT: 801 859
# instance, several teenagers play games without rest, which
#
# 151 --------------------------
# []
#
# UNIT: 809 865
# , several teenagers play games without rest, which leads
#
# 152 --------------------------
# []
#
# UNIT: 811 868
# several teenagers play games without rest, which leads to
#
# 153 --------------------------
# []
#
# UNIT: 819 875
# teenagers play games without rest, which leads to health
#
# 154 --------------------------
# []
#
# UNIT: 829 886
# play games without rest, which leads to health depression
#
# 155 --------------------------
# []
#
# UNIT: 834 887
# games without rest, which leads to health depression,
#
# 156 --------------------------
# []
#
# UNIT: 840 889
# without rest, which leads to health depression, a
#
# 157 --------------------------
# []
#
# UNIT: 848 897
# rest, which leads to health depression, a typical
#
# 158 --------------------------
# []
#
# UNIT: 852 905
# , which leads to health depression, a typical example
#
# 159 --------------------------
# []
#
# UNIT: 854 908
# which leads to health depression, a typical example is
#
# 160 --------------------------
# []
#
# UNIT: 860 912
# leads to health depression, a typical example is the
#
# 161 --------------------------
# []
#
# UNIT: 866 918
# to health depression, a typical example is the death
#
# 162 --------------------------
# []
#
# UNIT: 869 921
# health depression, a typical example is the death of
#
# 163 --------------------------
# []
#
# UNIT: 876 928
# depression, a typical example is the death of Korean
#
# 164 --------------------------
# []
#
# UNIT: 886 934
# , a typical example is the death of Korean gamer
#
# 165 --------------------------
# []
#
# UNIT: 888 935
# a typical example is the death of Korean gamer,
#
# 166 --------------------------
# []
#
# UNIT: 890 939
# typical example is the death of Korean gamer, who
#
# 167 --------------------------
# []
#
# UNIT: 898 943
# example is the death of Korean gamer, who had
#
# 168 --------------------------
# []
#
# UNIT: 906 945
# is the death of Korean gamer, who had a
#
# 169 --------------------------
# []
#
# UNIT: 909 949
# the death of Korean gamer, who had a non
#
# 170 --------------------------
# []
#
# UNIT: 913 950
# death of Korean gamer, who had a non-
#
# 171 --------------------------
# []
#
# UNIT: 919 954
# of Korean gamer, who had a non-stop
#
# 172 --------------------------
# []
#
# UNIT: 922 962
# Korean gamer, who had a non-stop playing
#
# 173 --------------------------
# []
#
# UNIT: 929 966
# gamer, who had a non-stop playing for
#
# 174 --------------------------
# []
#
# UNIT: 934 968
# , who had a non-stop playing for 3
#
# 175 --------------------------
# []
#
# UNIT: 936 973
# who had a non-stop playing for 3 days
#
# 176 --------------------------
# []
#
# UNIT: 940 974
# had a non-stop playing for 3 days.
#
# 177 --------------------------
# []
#
# UNIT: 944 975
# a non-stop playing for 3 days.
#
#
# 178 --------------------------
# []
#
# UNIT: 946 982
# non-stop playing for 3 days.
# Finally
#
# 179 --------------------------
# []
#
# UNIT: 949 983
# -stop playing for 3 days.
# Finally,
#
# 180 --------------------------
# []
#
# UNIT: 950 988
# stop playing for 3 days.
# Finally, even
#
# 181 --------------------------
# []
#
# UNIT: 955 995
# playing for 3 days.
# Finally, even people
#
# 182 --------------------------
# []
#
# UNIT: 963 999
# for 3 days.
# Finally, even people who
#
# 183 --------------------------
# []
#
# UNIT: 967 1003
# 3 days.
# Finally, even people who are
#
# 184 --------------------------
# []
#
# UNIT: 969 1007
# days.
# Finally, even people who are not
#
# 185 --------------------------
# []
#
# UNIT: 973 1018
# .
# Finally, even people who are not interested
#
# 186 --------------------------
# []
#
# UNIT: 974 1021
#
# Finally, even people who are not interested in
#
# 187 --------------------------
# []
#
# UNIT: 975 1028
# Finally, even people who are not interested in online
#
# 188 --------------------------
# []
#
# UNIT: 982 1033
# , even people who are not interested in online game
#
# 189 --------------------------
# []
#
# UNIT: 984 1037
# even people who are not interested in online game can
#
# 190 --------------------------
# []
#
# UNIT: 989 1043
# people who are not interested in online game can still
#
# 191 --------------------------
# []
#
# UNIT: 996 1046
# who are not interested in online game can still be
#
# 192 --------------------------
# []
#
# UNIT: 1000 1057
# are not interested in online game can still be negatively
#
# 193 --------------------------
# []
#
# UNIT: 1004 1066
# not interested in online game can still be negatively affected
#
# 194 --------------------------
# []
#
# UNIT: 1008 1069
# interested in online game can still be negatively affected by
#
# 195 --------------------------
# []
#
# UNIT: 1019 1075
# in online game can still be negatively affected by using
#
# 196 --------------------------
# []
#
# UNIT: 1022 1084
# online game can still be negatively affected by using computer
#
# 197 --------------------------
# []
#
# UNIT: 1029 1088
# game can still be negatively affected by using computer too
#
# 198 --------------------------
# []
#
# UNIT: 1034 1093
# can still be negatively affected by using computer too much
#
# 199 --------------------------
# []
#
# UNIT: 1038 1094
# still be negatively affected by using computer too much.
#
# 200 --------------------------
# []
#
# UNIT: 1044 1099
# be negatively affected by using computer too much. Some
#
# 201 --------------------------
# []
#
# UNIT: 1047 1106
# negatively affected by using computer too much. Some social
#
# 202 --------------------------
# []
#
# UNIT: 1058 1114
# affected by using computer too much. Some social surveys
#
# 203 --------------------------
# []
#
# UNIT: 1067 1119
# by using computer too much. Some social surveys have
#
# 204 --------------------------
# []
#
# UNIT: 1070 1125
# using computer too much. Some social surveys have shown
#
# 205 --------------------------
# []
#
# UNIT: 1076 1130
# computer too much. Some social surveys have shown that
#
# 206 --------------------------
# []
#
# UNIT: 1085 1132
# too much. Some social surveys have shown that a
#
# 207 --------------------------
# []
#
# UNIT: 1089 1136
# much. Some social surveys have shown that a few
#
# 208 --------------------------
# []
#
# UNIT: 1093 1145
# . Some social surveys have shown that a few children
#
# 209 --------------------------
# []
#
# UNIT: 1095 1149
# Some social surveys have shown that a few children use
#
# 210 --------------------------
# []
#
# UNIT: 1100 1158
# social surveys have shown that a few children use computer
#
# 211 --------------------------
# []
#
# UNIT: 1107 1162
# surveys have shown that a few children use computer for
#
# 212 --------------------------
# []
#
# UNIT: 1115 1171
# have shown that a few children use computer for studying
#
# 213 --------------------------
# []
#
# UNIT: 1120 1179
# shown that a few children use computer for studying purpose
#
# 214 --------------------------
# []
#
# UNIT: 1126 1180
# that a few children use computer for studying purpose,
#
# 215 --------------------------
# []
#
# UNIT: 1131 1185
# a few children use computer for studying purpose, most
#
# 216 --------------------------
# []
#
# UNIT: 1133 1188
# few children use computer for studying purpose, most of
#
# 217 --------------------------
# []
#
# UNIT: 1137 1193
# children use computer for studying purpose, most of them
#
# 218 --------------------------
# []
#
# UNIT: 1146 1197
# use computer for studying purpose, most of them are
#
# 219 --------------------------
# []
#
# UNIT: 1150 1207
# computer for studying purpose, most of them are attracted
#
# 220 --------------------------
# []
#
# UNIT: 1159 1210
# for studying purpose, most of them are attracted by
#
# 221 --------------------------
# []
#
# UNIT: 1163 1219
# studying purpose, most of them are attracted by facebook
#
# 222 --------------------------
# []
#
# UNIT: 1172 1220
# purpose, most of them are attracted by facebook,
#
# 223 --------------------------
# []
#
# UNIT: 1179 1225
# , most of them are attracted by facebook, blog
#
# 224 --------------------------
# []
#
# UNIT: 1181 1226
# most of them are attracted by facebook, blog,
#
# 225 --------------------------
# []
#
# UNIT: 1186 1230
# of them are attracted by facebook, blog, etc
#
# 226 --------------------------
# []
#
# UNIT: 1189 1231
# them are attracted by facebook, blog, etc.
#
# 227 --------------------------
# []
#
# UNIT: 1194 1239
# are attracted by facebook, blog, etc. instead
#
# 228 --------------------------
# []
#
# UNIT: 1198 1240
# attracted by facebook, blog, etc. instead.
#
# 229 --------------------------
# []
#
# UNIT: 1208 1244
# by facebook, blog, etc. instead. Due
#
# 230 --------------------------
# []
#
# UNIT: 1211 1247
# facebook, blog, etc. instead. Due to
#
# 231 --------------------------
# []
#
# UNIT: 1219 1252
# , blog, etc. instead. Due to this
#
# 232 --------------------------
# []
#
# UNIT: 1221 1260
# blog, etc. instead. Due to this neglect
#
# 233 --------------------------
# []
#
# UNIT: 1225 1261
# , etc. instead. Due to this neglect,
#
# 234 --------------------------
# []
#
# UNIT: 1227 1266
# etc. instead. Due to this neglect, they
#
# 235 --------------------------
# []
#
# UNIT: 1230 1271
# . instead. Due to this neglect, they will
#
# 236 --------------------------
# []
#
# UNIT: 1232 1276
# instead. Due to this neglect, they will have
#
# 237 --------------------------
# []
#
# UNIT: 1239 1278
# . Due to this neglect, they will have a
#
# 238 --------------------------
# []
#
# UNIT: 1241 1282
# Due to this neglect, they will have a bad
#
# 239 --------------------------
# []
#
# UNIT: 1245 1289
# to this neglect, they will have a bad result
#
# 240 --------------------------
# []
#
# UNIT: 1248 1292
# this neglect, they will have a bad result in
#
# 241 --------------------------
# [((1253, 1299), (1262, 1299, 'Premise', 348))]
#
# UNIT: 1253 1299
# neglect, they will have a bad result in school
#
# PREMISE: 1262 1299
# they will have a bad result in school
#
# 242 --------------------------
# [((1260, 1307), (1262, 1299, 'Premise', 348))]
#
# UNIT: 1260 1307
# , they will have a bad result in school because
#
# PREMISE: 1262 1299
# they will have a bad result in school
#
# 243 --------------------------
# [((1262, 1312), (1262, 1299, 'Premise', 348))]
#
# UNIT: 1262 1312
# they will have a bad result in school because when
#
# PREMISE: 1262 1299
# they will have a bad result in school
#
# 244 --------------------------
# []
#
# UNIT: 1267 1317
# will have a bad result in school because when they
#
# 245 --------------------------
# []
#
# UNIT: 1272 1321
# have a bad result in school because when they can
#
# 246 --------------------------
# []
#
# UNIT: 1277 1325
# a bad result in school because when they can not
#
# 247 --------------------------
# []
#
# UNIT: 1279 1330
# bad result in school because when they can not live
#
# 248 --------------------------
# []
#
# UNIT: 1283 1338
# result in school because when they can not live without
#
# 249 --------------------------
# []
#
# UNIT: 1290 1347
# in school because when they can not live without internet
#
# 250 --------------------------
# []
#
# UNIT: 1293 1348
# school because when they can not live without internet,
#
# 251 --------------------------
# []
#
# UNIT: 1300 1353
# because when they can not live without internet, they
#
# 252 --------------------------
# []
#
# UNIT: 1308 1358
# when they can not live without internet, they will
#
# 253 --------------------------
# []
#
# UNIT: 1313 1363
# they can not live without internet, they will have
#
# 254 --------------------------
# []
#
# UNIT: 1318 1366
# can not live without internet, they will have no
#
# 255 --------------------------
# []
#
# UNIT: 1322 1371
# not live without internet, they will have no time
#
# 256 --------------------------
# []
#
# UNIT: 1326 1375
# live without internet, they will have no time for
#
# 257 --------------------------
# []
#
# UNIT: 1331 1381
# without internet, they will have no time for their
#
# 258 --------------------------
# []
#
# UNIT: 1339 1390
# internet, they will have no time for their studying
#
# 259 --------------------------
# []
#
# UNIT: 1347 1391
# , they will have no time for their studying.
#
# 260 --------------------------
# []
#
# UNIT: 1349 1392
# they will have no time for their studying.
#
#
# 261 --------------------------
# []
#
# UNIT: 1354 1394
# will have no time for their studying.
# In
#
# 262 --------------------------
# []
#
# UNIT: 1359 1405
# have no time for their studying.
# In conclusion
#
# 263 --------------------------
# []
#
# UNIT: 1364 1406
# no time for their studying.
# In conclusion,
#
# 264 --------------------------
# []
#
# UNIT: 1367 1415
# time for their studying.
# In conclusion, although
#
# 265 --------------------------
# []
#
# UNIT: 1372 1418
# for their studying.
# In conclusion, although it
#
# 266 --------------------------
# []
#
# UNIT: 1376 1421
# their studying.
# In conclusion, although it is
#
# 267 --------------------------
# []
#
# UNIT: 1382 1432
# studying.
# In conclusion, although it is undeniable
#
# 268 --------------------------
# []
#
# UNIT: 1390 1437
# .
# In conclusion, although it is undeniable that
#
# 269 --------------------------
# []
#
# UNIT: 1391 1446
#
# In conclusion, although it is undeniable that computer
#
# 270 --------------------------
# []
#
# UNIT: 1392 1449
# In conclusion, although it is undeniable that computer is
#
# 271 --------------------------
# []
#
# UNIT: 1395 1451
# conclusion, although it is undeniable that computer is a
#
# 272 --------------------------
# []
#
# UNIT: 1405 1459
# , although it is undeniable that computer is a crucial
#
# 273 --------------------------
# []
#
# UNIT: 1407 1464
# although it is undeniable that computer is a crucial part
#
# 274 --------------------------
# []
#
# UNIT: 1416 1467
# it is undeniable that computer is a crucial part of
#
# 275 --------------------------
# []
#
# UNIT: 1419 1473
# is undeniable that computer is a crucial part of human
#
# 276 --------------------------
# []
#
# UNIT: 1422 1478
# undeniable that computer is a crucial part of human life
#
# 277 --------------------------
# []
#
# UNIT: 1433 1479
# that computer is a crucial part of human life,
#
# 278 --------------------------
# []
#
# UNIT: 1438 1482
# computer is a crucial part of human life, it
#
# 279 --------------------------
# []
#
# UNIT: 1447 1488
# is a crucial part of human life, it still
#
# 280 --------------------------
# []
#
# UNIT: 1450 1492
# a crucial part of human life, it still has
#
# 281 --------------------------
# []
#
# UNIT: 1452 1496
# crucial part of human life, it still has its
#
# 282 --------------------------
# []
#
# UNIT: 1460 1500
# part of human life, it still has its bad
#
# 283 --------------------------
# []
#
# UNIT: 1465 1505
# of human life, it still has its bad side
#
# 284 --------------------------
# []
#
# UNIT: 1468 1506
# human life, it still has its bad side,
#
# 285 --------------------------
# []
#
# UNIT: 1474 1517
# life, it still has its bad side, especially
#
# 286 --------------------------
# []
#
# UNIT: 1478 1521
# , it still has its bad side, especially for
# 287 --------------------------
# [((1480, 1530), (1480, 1530, 'Claim', 338))]
#
# UNIT: 1480 1530
# it still has its bad side, especially for children
#
# CLAIM: 1480 1530
# it still has its bad side, especially for children
#
# 288 --------------------------
# []
#
# UNIT: 1483 1531
# still has its bad side, especially for children.
#
# 289 --------------------------
# []
#
# UNIT: 1489 1538
# has its bad side, especially for children. People
#
# 290 --------------------------
# []
#
# UNIT: 1493 1545
# its bad side, especially for children. People should
#
# 291 --------------------------
# []
#
# UNIT: 1497 1551
# bad side, especially for children. People should learn
#
# 292 --------------------------
# []
#
# UNIT: 1501 1555
# side, especially for children. People should learn how
#
# 293 --------------------------
# []
#
# UNIT: 1505 1558
# , especially for children. People should learn how to
#
# 294 --------------------------
# []
#
# UNIT: 1507 1562
# especially for children. People should learn how to use
#
# 295 --------------------------
# []
#
# UNIT: 1518 1565
# for children. People should learn how to use it
#
# 296 --------------------------
# []
#
# UNIT: 1522 1574
# children. People should learn how to use it properly
#
# 297 --------------------------
# []
#
# UNIT: 1530 1577
# . People should learn how to use it properly to
#
# 298 --------------------------
# []
#
# UNIT: 1532 1582
# People should learn how to use it properly to make
#
# 299 --------------------------
# []
#
# UNIT: 1539 1585
# should learn how to use it properly to make it
#
# 300 --------------------------
# []
#
# UNIT: 1546 1588
# learn how to use it properly to make it an
#
# 301 --------------------------
# []
#
# UNIT: 1552 1598
# how to use it properly to make it an effective
#
# 302 --------------------------
# []
#
# UNIT: 1556 1603
# to use it properly to make it an effective tool
#
# 303 --------------------------
# []
#
# UNIT: 1559 1611
# use it properly to make it an effective tool because
#
# 304 --------------------------
# []
#
# UNIT: 1563 1620
# it properly to make it an effective tool because computer
#
# 305 --------------------------
# []
#
# UNIT: 1566 1627
# properly to make it an effective tool because computer should
#
# 306 --------------------------
# []
#
# UNIT: 1575 1630
# to make it an effective tool because computer should be
#
# 307 --------------------------
# []
#
# UNIT: 1578 1635
# make it an effective tool because computer should be used
#
# 308 --------------------------
# []
#
# UNIT: 1583 1639
# it an effective tool because computer should be used not
#
# 309 --------------------------
# []
#
# UNIT: 1586 1644
# an effective tool because computer should be used not only
#
# 310 --------------------------
# []
#
# UNIT: 1589 1648
# effective tool because computer should be used not only for
#
# 311 --------------------------
# []
#
# UNIT: 1599 1661
# tool because computer should be used not only for entertaining
#
# 312 --------------------------
# []
#
# UNIT: 1604 1665
# because computer should be used not only for entertaining but
#
# 313 --------------------------
# []
#
# UNIT: 1612 1670
# computer should be used not only for entertaining but also
#
# 314 --------------------------
# []
#
# UNIT: 1621 1674
# should be used not only for entertaining but also for
#
# 315 --------------------------
# []
#
# UNIT: 1628 1682
# be used not only for entertaining but also for working
#
# 316 --------------------------
# []
#
# UNIT: 1631 1686
# used not only for entertaining but also for working and
#
# 317 --------------------------
# []
#
# UNIT: 1636 1695
# not only for entertaining but also for working and studying
#
# 318 --------------------------
# []
#
# UNIT: 1640 1703
# only for entertaining but also for working and studying purpose
#
# 319 --------------------------
# []
#
# UNIT: 1645 1704
# for entertaining but also for working and studying purpose.
#
# 320 --------------------------
# []
#
# UNIT: 1649 1705
# entertaining but also for working and studying purpose.
#
#
# 321 --------------------------
# []
#
# UNIT: 1662 1705
# but also for working and studying purpose.
#
#
# 322 --------------------------
# []
#
# UNIT: 1666 1705
# also for working and studying purpose.
#
#
# 323 --------------------------
# []
#
# UNIT: 1671 1705
# for working and studying purpose.
#
#
# 324 --------------------------
# []
#
# UNIT: 1675 1705
# working and studying purpose.
#
#
# 325 --------------------------
# []
#
# UNIT: 1683 1705
# and studying purpose.
#
#
# 326 --------------------------
# []
#
# UNIT: 1687 1705
# studying purpose.
#
#
# 327 --------------------------
# []
#
# UNIT: 1696 1705
# purpose.
#
#
# 328 --------------------------
# []
#
# UNIT: 1703 1705
# .
#
#
# 329 --------------------------
# []
#
# UNIT: 1704 1705

# %%
for i, u in enumerate(units):
    if u._.label:
        span_start = u[0].idx
        span_end = u[-1].idx  + len(u[-1])
        
        lis = [((span_start, span_end),(row['start_ind'], row['end_ind'], row['ADU_type'],row_ind)) for row_ind,row in adu24.iterrows() if span_start<= row['start_ind'] and span_end>= row['end_ind']]
        
        print(i,'--------------------------')
        print(lis,"\n")
# Out:
# 59 --------------------------
# [((311, 373), (311, 373, 'Claim', 340))]
#
# 113 --------------------------
# [((611, 663), (619, 663, 'Premise', 350))]
#
# 114 --------------------------
# [((617, 664), (619, 663, 'Premise', 350))]
#
# 115 --------------------------
# [((619, 667), (619, 663, 'Premise', 350))]
#
# 241 --------------------------
# [((1253, 1299), (1262, 1299, 'Premise', 348))]
#
# 242 --------------------------
# [((1260, 1307), (1262, 1299, 'Premise', 348))]
#
# 243 --------------------------
# [((1262, 1312), (1262, 1299, 'Premise', 348))]
#
# 287 --------------------------
# [((1480, 1530), (1480, 1530, 'Claim', 338))]
